# %%
import pandas as pd
import numpy as np
import os
import json
import jsonlines
import datetime
import great_expectations as ge
from sqlalchemy import create_engine
import pymysql
import yaml
from sqlalchemy import create_engine
from sqlalchemy import text



pd.set_option('display.max_rows', 100)  # Set maximum rows to 100
pd.set_option('display.max_columns', 100) # Set maximum columns to 20

# %%
# pip install great-expectations

# %%
root_dir = os.getcwd()

# %%
##reading csvs for detail data quality checks.

brands_df = pd.read_csv(os.path.join(root_dir,'brands.csv'))
users_df = pd.read_csv(os.path.join(root_dir,'users.csv'))
receipts_df = pd.read_csv(os.path.join(root_dir,'receipts.csv'))
rewards_receipts_df = pd.read_csv(os.path.join(root_dir,'rewards_receipts.csv'))

# %% [markdown]
# ## Data Quality issues
#
# 1) Some of the purchase dates are after the scanning date. (TBD: check how data behaves in this scenario)
# 2) Barcodes don't have specific shape (for example some barcodes are 4 digits) - this is maybe due to the fact that the items dont have barcodes. (TBD: check how data behanves in this scenario)
# 3) Not an issue but remember this: Same brandcode can have different barcode.
# 4) Bar code is present but BrandCode is missing in the rewards_receipts_df. But in their description, the first word of the description. This word can be used to subsititute (curious to know if this has any impact in the brand related questions)
# 5) Foreign key between rewards_receipts df and brands could be brand code
# 6) Not all brandcodes (non nans) in rewards_receipts_df are present in brands_df. (example difference: 'Ben & jerry's' and 'BEN AND JERRY') - This is a data quality issue. Ed2: '7 UP' and '7UP'
# 7) Duplicates in user_df and brands_df
# 8) Empty rewards_receipt_df_list are present.
# 9) Letters in Barcodes

# %%
#modify the code
receipts_df[receipts_df['rewardsReceiptItemList'].isna()]
# Out:
#       bonusPointsEarned bonusPointsEarnedReason  pointsEarned  \
# 71                  NaN                     NaN           NaN
# 93                  NaN                     NaN           NaN
# 149                 NaN                     NaN           NaN
# 175                 NaN                     NaN           NaN
# 212                 NaN                     NaN           NaN
# ...                 ...                     ...           ...
# 1110                NaN                     NaN           NaN
# 1111                NaN                     NaN           NaN
# 1115                NaN                     NaN           NaN
# 1116                NaN                     NaN           NaN
# 1118                NaN                     NaN           NaN
#
#       purchasedItemCount rewardsReceiptItemList rewardsReceiptStatus  \
# 71                   NaN                    NaN            SUBMITTED
# 93                   NaN                    NaN            SUBMITTED
# 149                  NaN                    NaN            SUBMITTED
# 175                  0.0                    NaN             REJECTED
# 212                  NaN                    NaN            SUBMITTED
# ...                  ...                    ...                  ...
# 1110                 NaN                    NaN            SUBMITTED
# 1111                 NaN                    NaN            SUBMITTED
# 1115                 NaN                    NaN            SUBMITTED
# 1116                 NaN                    NaN            SUBMITTED
# 1118                 NaN                    NaN            SUBMITTED
#
#       totalSpent                    userId                receipt_id  \
# 71           NaN  5a43c08fe4b014fd6b6a0612  5ff475820a7214ada10005cf
# 93           NaN  5a43c08fe4b014fd6b6a0612  5ff5ecb90a7214ada10005f9
# 149          NaN  5ff7264e8f142f11dd189504  5ff726860a720f05230005ec
# 175          0.0  5ff8da28b3348b11c9337ac6  5ff8da570a720f05c5000015
# 212          NaN  59c124bae4b0299e55b0f330  5ffce8570a7214ad4e003e6f
# ...          ...                       ...                       ...
# 1110         NaN  5fc961c3b8cfca11a077dd33  603c6adf0a720fde1000039a
# 1111         NaN  5fc961c3b8cfca11a077dd33  603c9e6e0a720fde100003c7
# 1115         NaN  5fc961c3b8cfca11a077dd33  603d0b710a720fde1000042a
# 1116         NaN  5fc961c3b8cfca11a077dd33  603cf5290a720fde10000413
# 1118         NaN  5fc961c3b8cfca11a077dd33  603c4fea0a7217c72c000389
#
#             created_date_time        scanned_date_time finished_date_time  \
# 71    2021-01-05 08:19:46.000  2021-01-05 08:19:46.000                NaN
# 93    2021-01-06 11:00:40.000  2021-01-06 11:00:40.000                NaN
# 149   2021-01-07 09:19:34.000  2021-01-07 09:19:34.000                NaN
# 175   2021-01-08 16:19:03.000  2021-01-08 16:19:03.000                NaN
# 212   2021-01-11 18:07:51.000  2021-01-11 18:07:51.000                NaN
# ...                       ...                      ...                ...
# 1110  2021-02-28 22:17:35.736  2021-02-28 22:17:35.736                NaN
# 1111  2021-03-01 01:57:34.307  2021-03-01 01:57:34.307                NaN
# 1115  2021-03-01 09:42:41.873  2021-03-01 09:42:41.873                NaN
# 1116  2021-03-01 08:07:37.664  2021-03-01 08:07:37.664                NaN
# 1118  2021-02-28 20:22:34.962  2021-02-28 20:22:34.962                NaN
#
#              modify_date_time pointsAwarded_date_time purchased_date_time
# 71    2021-01-05 08:19:46.000                     NaN                 NaN
# 93    2021-01-06 11:00:40.000                     NaN                 NaN
# 149   2021-01-07 09:19:34.000                     NaN                 NaN
# 175   2021-01-08 16:19:04.000                     NaN                 NaN
# 212   2021-01-11 18:07:51.000                     NaN                 NaN
# ...                       ...                     ...                 ...
# 1110  2021-02-28 22:17:35.736                     NaN                 NaN
# 1111  2021-03-01 01:57:34.307                     NaN                 NaN
# 1115  2021-03-01 09:42:41.873                     NaN                 NaN
# 1116  2021-03-01 08:07:37.664                     NaN                 NaN
# 1118  2021-02-28 20:22:34.962                     NaN                 NaN
#
# [440 rows x 15 columns]

# %%
rewards_receipts_df['barcode'].fillna(0)
# Out:
# 0               4011
# 1               4011
# 2       028400642255
# 3                  0
# 4               4011
#             ...
# 6936      B07BRRLSVC
# 6937      B076FJ92M4
# 6938      B07BRRLSVC
# 6939      B076FJ92M4
# 6940      B07BRRLSVC
# Name: barcode, Length: 6941, dtype: object

# %%
rewards_receipts_df[(rewards_receipts_df['brandCode'] == 'KLEENEX') & (rewards_receipts_df['barcode'] != "036000391718")]
# Out:
#            barcode                                        description  \
# 2862  036000119749  KLEENEX POCKET RCH IN WRP FACIAL TISSUE 2 PLY ...
#
#       finalPrice  itemPrice needsFetchReview  partnerItemId  \
# 2862        5.64       5.64              NaN           1202
#
#      preventTargetGapPoints  quantityPurchased  userFlaggedBarcode  \
# 2862                    NaN                2.0                 NaN
#
#      userFlaggedNewItem  ...  originalMetaBriteQuantityPurchased  \
# 2862                NaN  ...                                 NaN
#
#       pointsEarned targetPrice competitiveProduct originalFinalPrice  \
# 2862          56.4         NaN                NaN                NaN
#
#      originalMetaBriteItemPrice deleted priceAfterCoupon  \
# 2862                        NaN     NaN              NaN
#
#                                     metabriteCampaignId  \
# 2862  KLEENEX TRUSTED CARE FACIAL TISSUES 1 - 59 COU...
#
#                     receipt_id
# 2862  60099c3c0a7214ad89000135
#
# [1 rows x 35 columns]

# %%
rewards_receipts_df[rewards_receipts_df['brandCode'] == 'KLEENEX'].groupby('description').agg({'description':'size'}).rename(columns = {'description':'count'}).sort_values(by = 'count',ascending = False)
# Out:
#                                                     count
# description
# KLEENEX POP UP RECTANGLE BOX FACIAL TISSUE 2 PL...     87
# KLEENEX POCKET RCH IN WRP FACIAL TISSUE 2 PLY 8...      1

# %%
rewards_receipts_df.groupby('brandCode').agg({'brandCode':'size'}).rename(columns = {'brandCode':'count'}).sort_values(by = 'count',ascending = False)
# Out:
#                 count
# brandCode
# HY-VEE            291
# BEN AND JERRYS    180
# PEPSI              93
# KROGER             89
# KLEENEX            88
# ...               ...
# GERM-X              1
# PURINA ONE          1
# GREY POUPON         1
# GRIMMWAY FARMS      1
# SABRA               1
#
# [227 rows x 1 columns]

# %%
##checking if unique brandcodes exist in receipt but not in brands

brandcodes_rewards_receipt = list(rewards_receipts_df['brandCode'].unique())
brandcodes_brands = list(brands_df['brandCode'].unique())
len(brandcodes_rewards_receipt)
missing_bar_codes = [x for x in brandcodes_rewards_receipt if x not in brandcodes_brands]
sorted(missing_bar_codes)

# %%
# Out:
# ['7UP',
#  'ADVIL',
#  'AMERICAN BEAUTY',
#  'ARROWHEAD',
#  'AZTECA',
#  'BANZA',
#  'BEAR CREEK COUNTRY KITCHENS',
#  'BEN AND JERRYS',
#  'BETTY CROCKER',
#  'BIC',
#  'BIGELOW',
#  'BLUE DIAMOND',
#  "BOAR'S HEAD",
#  'BORDEN',
#  'BOTA BOX',
#  'BRAND',
#  "BRASWELL'S",
#  'BUNNY',
#  "BUSH'S BEST",
#  'C&H',
#  'CADBURY',
#  'CAL-ORGANIC FARMS',
#  'CALIFIA FARMS',
#  "CAMPBELL'S",
#  'CARAMELLO',
#  'CHEERIOS',
#  'CHEESE',
#  'CHEEZ-IT',
#  'CHEX',
#  'CHICKEN OF THE SEA',
#  'CHIQUITA',
#  'CINNAMON TOAST CRUNCH',
#  'COKE',
#  'COLEMAN NATURAL',
#  "CONNIE'S PIZZA",
#  'CREST 3D WHITE',
#  'CRISPIX',
#  'DANNON',
#  'DARE',
#  'DELI',
#  'DIET COKE',
#  'DIGIORNO',
#  'DOLE',
#  'DR PEPPER',
#  'EDWARDS',
#  "EGGLAND'S BEST",
#  'EGGO',
#  'EL MONTEREY',
#  'ENERGIZER MAX',
#  'ESSENTIAL EVERYDAY',
#  'FAGE',
#  "FAMOUS DAVE'S",
#  "FLORIDA'S NATURAL",
#  'FOLGERS',
#  'FORTUNE YAKISOBA',
#  'FRANZ',
#  "FRENCH'S",
#  'FRESH EXPRESS',
#  'FRESH STEP',
#  'FRONTERA',
#  'GALLO FAMILY VINEYARDS',
#  'GENERAL MILLS',
#  'GERBER',
#  'GERM-X',
#  'GREEN GIANT',
#  'GRIMMWAY FARMS',
#  'HANOVER',
#  'HARVEST SNAPS',
#  'HATCH FARMS',
#  'HAWAIIAN',
#  "HEMPLER'S",
#  'HERITAGE FARM',
#  "HERSHEY'S KISSES",
#  'HEWLETT PACKARD',
#  'HIDDEN VALLEY',
#  'HILLSHIRE FARM',
#  'HONEY BUNCHES OF OATS',
#  'HORMEL',
#  'HY-VEE',
#  'HY-VEE SELECT',
#  "JACK DANIEL'S READY TO EAT",
#  "JACK LINK'S",
#  'JELLY BELLY',
#  'JENNIE-O',
#  'JIMMY DEAN',
#  'JOHN SOULES FOODS',
#  'JOHNSONVILLE',
#  'JUST BARE',
#  'KARO',
#  'KASHI',
#  "KELLOGG'S",
#  'KEMPS',
#  'KERR',
#  'KERRYGOLD',
#  'KIKKOMAN',
#  'KING ARTHUR FLOUR',
#  'KIT KAT',
#  'KITCHEN BASICS',
#  'KLARBRUNN',
#  'KRAFT EASY CHEESE',
#  'KRAZY GLUE',
#  'KROGER',
#  'KRUSTEAZ',
#  'LA BANDERITA',
#  "LAURA'S LEAN BEEF",
#  'LIGHT & FIT',
#  'LIGHT & FIT GREEK',
#  'LINDSAY',
#  'LINDT',
#  'LIPTON',
#  'LITEHOUSE',
#  'LUNDBERG FAMILY FARMS',
#  "MARIE CALLENDER'S",
#  "MARIE'S",
#  "MARTINELLI'S",
#  'MCCORMICK',
#  'MCCORMICK GRILL MATES',
#  "MERKT'S",
#  'MISSION',
#  'MORTON',
#  "MRS. CUBBISON'S",
#  "MRS. RENFRO'S",
#  'NABISCO',
#  "NATURE'S PATH ORGANIC",
#  'NESTLE',
#  'NUTELLA',
#  'NUTRI-GRAIN',
#  'OLD EL PASO',
#  'ORAL-B GLIDE',
#  'ORBIT',
#  'OREO',
#  'ORGANIC ROOT STIMULATOR',
#  'ORGANICVILLE',
#  'OVALTINE',
#  'PEARLS',
#  'PILLSBURY',
#  'PLAYTEX',
#  'POMPEIAN',
#  'POWER CRUNCH',
#  'PRINGLES',
#  'PRIVATE SELECTION',
#  'PROGRESSO',
#  'PURINA ONE',
#  'R.W. KNUDSEN',
#  'RAGU',
#  "REESE'S",
#  'RENUZIT',
#  'RITZ',
#  'RITZ TOASTED CHIPS',
#  'ROSARITA',
#  'SABRA',
#  "SCHWEBEL'S",
#  'SHOPRITE',
#  'SIGNATURE',
#  'SIGNATURE KITCHEN',
#  'SIMPLE TRUTH',
#  'SIMPLE TRUTH ORGANIC',
#  'SIMPLY POTATOES',
#  'SKITTLES',
#  'SMITHFIELD',
#  'SO DELICIOUS',
#  'SPARKLING ICE',
#  'SPECIAL K',
#  'STARKIST',
#  "STOUFFER'S",
#  "STOUFFER'S CLASSICS",
#  'TAYLOR FARMS',
#  'TEMPTATIONS',
#  'THAI KITCHEN',
#  "THAT'S SMART!",
#  'THOMAS',
#  'THOMAS ENGLISH MUFFINS',
#  "THOMAS'",
#  'TIC TAC',
#  'TILLAMOOK',
#  'TOLL HOUSE',
#  'TOP FLIGHT',
#  'TROLLI',
#  'TYSON',
#  "VAN DE KAMP'S",
#  'VITAL FARMS ALFRESCO EGGS',
#  "WELCH'S",
#  'WINGSTOP',
#  'WISHBONE',
#  'WONDERFUL',
#  'ZESTA']

# %%
##checking missing brandcodes

rewards_receipts_df['brandCode'].isna().sum()
# Out:
# 4341

# %%
rewards_receipts_df.shape
# Out:
# (6941, 35)

# %%
rewards_receipts_df[rewards_receipts_df['brandCode'].isna()]
# Out:
#            barcode                                        description  \
# 0             4011                                     ITEM NOT FOUND
# 1             4011                                     ITEM NOT FOUND
# 2     028400642255  DORITOS TORTILLA CHIP SPICY SWEET CHILI REDUCE...
# 3              NaN                                                NaN
# 4             4011                                     ITEM NOT FOUND
# ...            ...                                                ...
# 6936    B07BRRLSVC  thindust summer face mask - sun protection nec...
# 6937    B076FJ92M4  mueller austria hypergrind precision electric ...
# 6938    B07BRRLSVC  thindust summer face mask - sun protection nec...
# 6939    B076FJ92M4  mueller austria hypergrind precision electric ...
# 6940    B07BRRLSVC  thindust summer face mask - sun protection nec...
#
#       finalPrice  itemPrice needsFetchReview  partnerItemId  \
# 0          26.00      26.00            False              1
# 1           1.00       1.00              NaN              1
# 2          10.00      10.00             True              2
# 3            NaN        NaN            False              1
# 4          28.00      28.00            False              1
# ...          ...        ...              ...            ...
# 6936       11.99      11.99              NaN              1
# 6937       22.97      22.97              NaN              0
# 6938       11.99      11.99              NaN              1
# 6939       22.97      22.97              NaN              0
# 6940       11.99      11.99              NaN              1
#
#      preventTargetGapPoints  quantityPurchased  userFlaggedBarcode  \
# 0                      True                5.0        4.011000e+03
# 1                       NaN                1.0                 NaN
# 2                      True                1.0        2.840064e+10
# 3                      True                NaN        4.011000e+03
# 4                      True                4.0        4.011000e+03
# ...                     ...                ...                 ...
# 6936                    NaN                1.0                 NaN
# 6937                    NaN                1.0                 NaN
# 6938                    NaN                1.0                 NaN
# 6939                    NaN                1.0                 NaN
# 6940                    NaN                1.0                 NaN
#
#      userFlaggedNewItem  ...  originalMetaBriteQuantityPurchased  \
# 0                  True  ...                                 NaN
# 1                   NaN  ...                                 NaN
# 2                  True  ...                                 NaN
# 3                  True  ...                                 NaN
# 4                  True  ...                                 NaN
# ...                 ...  ...                                 ...
# 6936                NaN  ...                                 NaN
# 6937                NaN  ...                                 NaN
# 6938                NaN  ...                                 NaN
# 6939                NaN  ...                                 NaN
# 6940                NaN  ...                                 NaN
#
#       pointsEarned targetPrice competitiveProduct originalFinalPrice  \
# 0              NaN         NaN                NaN                NaN
# 1              NaN         NaN                NaN                NaN
# 2              NaN         NaN                NaN                NaN
# 3              NaN         NaN                NaN                NaN
# 4              NaN         NaN                NaN                NaN
# ...            ...         ...                ...                ...
# 6936           NaN         NaN                NaN                NaN
# 6937           NaN         NaN                NaN                NaN
# 6938           NaN         NaN                NaN                NaN
# 6939           NaN         NaN                NaN                NaN
# 6940           NaN         NaN                NaN                NaN
#
#      originalMetaBriteItemPrice deleted priceAfterCoupon  metabriteCampaignId  \
# 0                           NaN     NaN              NaN                  NaN
# 1                           NaN     NaN              NaN                  NaN
# 2                           NaN     NaN              NaN                  NaN
# 3                           NaN     NaN              NaN                  NaN
# 4                           NaN     NaN              NaN                  NaN
# ...                         ...     ...              ...                  ...
# 6936                        NaN     NaN            11.99                  NaN
# 6937                        NaN     NaN            22.97                  NaN
# 6938                        NaN     NaN            11.99                  NaN
# 6939                        NaN     NaN            22.97                  NaN
# 6940                        NaN     NaN            11.99                  NaN
#
#                     receipt_id
# 0     5ff1e1eb0a720f0523000575
# 1     5ff1e1bb0a720f052300056b
# 2     5ff1e1bb0a720f052300056b
# 3     5ff1e1f10a720f052300057a
# 4     5ff1e1ee0a7214ada100056f
# ...                        ...
# 6936  603cc2bc0a720fde100003e9
# 6937  603cc0630a720fde100003e6
# 6938  603cc0630a720fde100003e6
# 6939  603ce7100a7217c72c000405
# 6940  603ce7100a7217c72c000405
#
# [4341 rows x 35 columns]

# %%
rewards_receipts_df[rewards_receipts_df['brandCode'].isna()].groupby('description').agg({'description':'size'}).rename(columns = {'description':'count'}).sort_values(by = 'count',ascending = False)
# Out:
#                                                     count
# description
# ITEM NOT FOUND                                        173
# KLARBRUNN 12PK 12 FL OZ                               120
# HUGGIES SIMPLY CLEAN PREMOISTENED WIPE FRAGRANC...     92
# MILLER LITE 24 PACK 12OZ CAN                           90
# COMP BOOK                                              73
# ...                                                   ...
# CRAFIS                                                  1
# COTTONELLE ULTRA COMFORT CARE MEGA ROLL 2 PLY 2...      1
# COS SARDINES WATER                                      1
# CORN NUTS Ranch - 1.7 oz. bag, 216 per case             1
# GREATVALUE LATGE NTTEEG2S                               1
#
# [1392 rows x 1 columns]

# %% [markdown]
# #### Concept of Data Quality.
#
# Rules:
# 1) Consistency
# 2) Validity
# 3) Uniqueness
# 4) Threshold
# 5) Completeness

# %% [markdown]
# Data Quality that come off my head:
#
# 1) Duplications
# 2) Possible outliers?
# 3) Checking if certain columns are actually unique: especially the proposed Primary Key
# 4) Missing values
# 5) Consistency in data types.
#
# Great expectations?

# %% [markdown]
# #### Data Quality checks using great expectations.

# %% [markdown]
# #### Primary key Tests:
#
# Here are the desginated primary keys for the 4 tables.
#
# 1) users_df : 'user_id'
# 2) brands_df: 'brand_id'
# 3) receipts_df: 'receipts_id'
# 4) rewards_receipts_df: ('receipt_id','partnerItemId')

# %% [markdown]
# #### For User_id table

# %%
#Existence of the primary key

context = ge.get_context()
data_source = context.data_sources.add_pandas("pandas")
data_asset = data_source.add_dataframe_asset(name="pd dataframe asset")

batch_definition = data_asset.add_batch_definition_whole_dataframe("batch definition")
batch = batch_definition.get_batch(batch_parameters={"dataframe": users_df})

#expect user_id to exist:
pk_user_expectation = ge.expectations.ExpectColumnToExist(column = 'user_id')
validation_result = batch.validate(pk_user_expectation)
print(validation_result['success'])
# Out:
# Calculating Metrics:   0%|          | 0/2 [00:00<?, ?it/s]
# True

# %%
users_df.head()
# Out:
#    active      role signUpSource state                   user_id  \
# 0    True  consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# 1    True  consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# 2    True  consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# 3    True  consumer        Email    WI  5ff1e1eacfcf6c399c274ae6
# 4    True  consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
#
#          created_date_time      lastLogin_date_time
# 0  2021-01-03 09:24:04.800  2021-01-03 09:25:37.858
# 1  2021-01-03 09:24:04.800  2021-01-03 09:25:37.858
# 2  2021-01-03 09:24:04.800  2021-01-03 09:25:37.858
# 3  2021-01-03 09:25:30.554  2021-01-03 09:25:30.597
# 4  2021-01-03 09:24:04.800  2021-01-03 09:25:37.858

# %% [markdown]
# ### Digging deep into user_df
# Data Quality on top of my head
#
# 1) user_id: exists? (PK test)
# 2) user_id: unique? (PK test)
# 3) if not unique: is it carried over other columns as well (in short if the whole data row is duplicate)
# 4) Missing values
# 5) last login date_time is after creation date_time
# 6) state is valid
# 7) Checking if defined Schema for role : consists only 'consumers'

# %%
### 1) user_id: exists?

if 'user_id' in users_df.columns:
    print('Test Passed - user_id exists in user_df')
else:
    print('Test Failed - user_id does not exist in user_df')
# Out:
# Test Passed - user_id exists in user_df

# %%
## Unique test:

context = ge.get_context()
data_source = context.data_sources.add_pandas("pandas")
data_asset = data_source.add_dataframe_asset(name="pd dataframe asset")

batch_definition = data_asset.add_batch_definition_whole_dataframe("batch definition")
batch = batch_definition.get_batch(batch_parameters={"dataframe": users_df})

#expect user_id to exist:
unique_user_expectation = ge.expectations.ExpectColumnValuesToBeUnique(column = 'user_id')
validation_result = batch.validate(unique_user_expectation)
print(validation_result)
# Out:
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# {
#   "result": {
#     "element_count": 495,
#     "unexpected_count": 353,
#     "unexpected_percent": 71.31313131313132,
#     "partial_unexpected_list": [
#       "5ff1e194b6a9d73a3a9f1052",
#       "5ff1e194b6a9d73a3a9f1052",
#       "5ff1e194b6a9d73a3a9f1052",
#       "5ff1e1eacfcf6c399c274ae6",
#       "5ff1e194b6a9d73a3a9f1052",
#       "5ff1e194b6a9d73a3a9f1052",
#       "5ff1e194b6a9d73a3a9f1052",
#       "5ff1e194b6a9d73a3a9f1052",
#       "5ff1e1eacfcf6c399c274ae6",
#       "5ff1e194b6a9d73a3a9f1052",
#       "5ff1e1eacfcf6c399c274ae6",
#       "5ff1e194b6a9d73a3a9f1052",
#       "5ff1e194b6a9d73a3a9f1052",
#       "5ff1e1eacfcf6c399c274ae6",
#       "5ff1e194b6a9d73a3a9f1052",
#       "5ff370c562fde912123a5e0e",
#       "5ff36d0362fde912123a5535",
#       "5ff370c562fde912123a5e0e",
#       "5ff36be7135e7011bcb856d3",
#       "5ff36d0362fde912123a5535"
#     ],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 71.31313131313132,
#     "unexpected_percent_nonmissing": 71.31313131313132,
#     "partial_unexpected_counts": [
#       {
#         "value": "5ff1e194b6a9d73a3a9f1052",
#         "count": 11
#       },
#       {
#         "value": "5ff1e1eacfcf6c399c274ae6",
#         "count": 4
#       },
#       {
#         "value": "5ff36d0362fde912123a5535",
#         "count": 2
#       },
#       {
#         "value": "5ff370c562fde912123a5e0e",
#         "count": 2
#       },
#       {
#         "value": "5ff36be7135e7011bcb856d3",
#         "count": 1
#       }
#     ],
#     "partial_unexpected_index_list": [
#       0,
#       1,
#       2,
#       3,
#       4,
#       5,
#       8,
#       10,
#       11,
#       12,
#       13,
#       14,
#       15,
#       18,
#       19,
#       20,
#       21,
#       24,
#       25,
#       26
#     ]
#   },
#   "meta": {},
#   "expectation_config": {
#     "meta": {},
#     "type": "expect_column_values_to_be_unique",
#     "kwargs": {
#       "batch_id": "pandas-pd dataframe asset",
#       "column": "user_id"
#     }
#   },
#   "success": false,
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# This is suspicious behaviour. There is a need to check if there are duplicate entries present in the table or just that duplicate user_ids exist

# %%
## Unique test:

context = ge.get_context()
data_source = context.data_sources.add_pandas("pandas")
data_asset = data_source.add_dataframe_asset(name="pd dataframe asset")

batch_definition = data_asset.add_batch_definition_whole_dataframe("batch definition")
batch = batch_definition.get_batch(batch_parameters={"dataframe": users_df})

#expect user_id to exist:
compound_unique_user_expectation = ge.expectations.ExpectCompoundColumnsToBeUnique(column_list = list(users_df.columns))
validation_result = batch.validate(compound_unique_user_expectation)
print(validation_result['result'])
# Out:
# Calculating Metrics:   0%|          | 0/9 [00:00<?, ?it/s]
# {'element_count': 495, 'unexpected_count': 353, 'unexpected_percent': 71.31313131313132, 'partial_unexpected_list': [{'active': True, 'role': 'consumer', 'signUpSource': 'Email', 'state': 'WI', 'user_id': '5ff1e194b6a9d73a3a9f1052', 'created_date_time': '2021-01-03 09:24:04.800', 'lastLogin_date_time': '2021-01-03 09:25:37.858'}, {'active': True, 'role': 'consumer', 'signUpSource': 'Email', 'state': 'WI', 'user_id': '5ff1e194b6a9d73a3a9f1052', 'created_date_time': '2021-01-03 09:24:04.800', 'lastLogin_date_time': '2021-01-03 09:25:37.858'}, {'active': True, 'role': 'consumer', 'signUpSource': 'Email', 'state': 'WI', 'user_id': '5ff1e194b6a9d73a3a9f1052', 'created_date_time': '2021-01-03 09:24:04.800', 'lastLogin_date_time': '2021-01-03 09:25:37.858'}, {'active': True, 'role': 'consumer', 'signUpSource': 'Email', 'state': 'WI', 'user_id': '5ff1e1eacfcf6c399c274ae6', 'created_date_time': '2021-01-03 09:25:30.554', 'lastLogin_date_time': '2021-01-03 09:25:30.597'}, {'active': True, 'role': 'consumer', 'signUpSource': 'Email', 'state': 'WI', 'user_id': '5ff1e194b6a9d73a3a9f1052', 'created_date_time': '2021-01-03 09:24:04.800', 'lastLogin_date_time': '2021-01-03 09:25:37.858'}, {'active': True, 'role': 'consumer', 'signUpSource': 'Email', 'state': 'WI', 'user_id': '5ff1e194b6a9d73a3a9f1052', 'created_date_time': '2021-01-03 09:24:04.800', 'lastLogin_date_time': '2021-01-03 09:25:37.858'}, {'active': True, 'role': 'consumer', 'signUpSource': 'Email', 'state': 'WI', 'user_id': '5ff1e194b6a9d73a3a9f1052', 'created_date_time': '2021-01-03 09:24:04.800', 'lastLogin_date_time': '2021-01-03 09:25:37.858'}, {'active': True, 'role': 'consumer', 'signUpSource': 'Email', 'state': 'WI', 'user_id': '5ff1e194b6a9d73a3a9f1052', 'created_date_time': '2021-01-03 09:24:04.800', 'lastLogin_date_time': '2021-01-03 09:25:37.858'}, {'active': True, 'role': 'consumer', 'signUpSource': 'Email', 'state': 'WI', 'user_id': '5ff1e1eacfcf6c399c274ae6', 'created_date_time': '2021-01-03 09:25:30.554', 'lastLogin_date_time': '2021-01-03 09:25:30.597'}, {'active': True, 'role': 'consumer', 'signUpSource': 'Email', 'state': 'WI', 'user_id': '5ff1e194b6a9d73a3a9f1052', 'created_date_time': '2021-01-03 09:24:04.800', 'lastLogin_date_time': '2021-01-03 09:25:37.858'}, {'active': True, 'role': 'consumer', 'signUpSource': 'Email', 'state': 'WI', 'user_id': '5ff1e1eacfcf6c399c274ae6', 'created_date_time': '2021-01-03 09:25:30.554', 'lastLogin_date_time': '2021-01-03 09:25:30.597'}, {'active': True, 'role': 'consumer', 'signUpSource': 'Email', 'state': 'WI', 'user_id': '5ff1e194b6a9d73a3a9f1052', 'created_date_time': '2021-01-03 09:24:04.800', 'lastLogin_date_time': '2021-01-03 09:25:37.858'}, {'active': True, 'role': 'consumer', 'signUpSource': 'Email', 'state': 'WI', 'user_id': '5ff1e194b6a9d73a3a9f1052', 'created_date_time': '2021-01-03 09:24:04.800', 'lastLogin_date_time': '2021-01-03 09:25:37.858'}, {'active': True, 'role': 'consumer', 'signUpSource': 'Email', 'state': 'WI', 'user_id': '5ff1e1eacfcf6c399c274ae6', 'created_date_time': '2021-01-03 09:25:30.554', 'lastLogin_date_time': '2021-01-03 09:25:30.597'}, {'active': True, 'role': 'consumer', 'signUpSource': 'Email', 'state': 'WI', 'user_id': '5ff1e194b6a9d73a3a9f1052', 'created_date_time': '2021-01-03 09:24:04.800', 'lastLogin_date_time': '2021-01-03 09:25:37.858'}, {'active': True, 'role': 'consumer', 'signUpSource': 'Email', 'state': 'WI', 'user_id': '5ff370c562fde912123a5e0e', 'created_date_time': '2021-01-04 13:47:17.776', 'lastLogin_date_time': '2021-01-04 13:50:50.563'}, {'active': True, 'role': 'consumer', 'signUpSource': 'Email', 'state': 'WI', 'user_id': '5ff36d0362fde912123a5535', 'created_date_time': '2021-01-04 13:31:15.973', 'lastLogin_date_time': '2021-01-04 13:34:42.944'}, {'active': True, 'role': 'consumer', 'signUpSource': 'Email', 'state': 'WI', 'user_id': '5ff370c562fde912123a5e0e', 'created_date_time': '2021-01-04 13:47:17.776', 'lastLogin_date_time': '2021-01-04 13:50:50.563'}, {'active': Tr ...

# %%
### To quantify the above impact even deeper:

duplicate_count_user_df = users_df.groupby(list(users_df.columns)).size().reset_index(name='count').sort_values(by='count', ascending=False)
duplicate_count_user_df[duplicate_count_user_df['count']>1].head()
# Out:
#      active         role signUpSource state                   user_id  \
# 162    True  fetch-staff        Email    NH  5fc961c3b8cfca11a077dd33
# 23     True     consumer        Email    WI  5ff5d15aeb7c7d12096d91a2
# 104    True     consumer        Email    WI  600fb1ac73c60b12049027bb
# 1      True     consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# 95     True     consumer        Email    WI  600987d77d983a11f63cfa92
#
#            created_date_time      lastLogin_date_time  count
# 162  2020-12-03 16:08:03.936  2021-02-26 16:39:16.799     20
# 23   2021-01-06 09:03:54.680  2021-01-06 09:08:10.009     18
# 104  2021-01-26 00:07:40.879  2021-01-26 00:11:23.950     16
# 1    2021-01-03 09:24:04.800  2021-01-03 09:25:37.858     11
# 95   2021-01-21 07:55:35.327  2021-01-21 07:59:21.063      9

# %% [markdown]
# there is a need to remove the duplicate entries and check for unqiur user_ids again, to make sure that all the remainign user_ids a re indeed unique.

# %%
# Drop duplicate rows (considering all columns)
users_df_no_duplicates = users_df.drop_duplicates()

# %%
## Unique test:

context = ge.get_context()
data_source = context.data_sources.add_pandas("pandas")
data_asset = data_source.add_dataframe_asset(name="pd dataframe asset")

batch_definition = data_asset.add_batch_definition_whole_dataframe("batch definition")
batch = batch_definition.get_batch(batch_parameters={"dataframe": users_df_no_duplicates})

#expect user_id to exist:
unique_user_expectation = ge.expectations.ExpectColumnValuesToBeUnique(column = 'user_id')
validation_result = batch.validate(unique_user_expectation)
print(validation_result)
# Out:
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# {
#   "result": {
#     "element_count": 212,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0,
#     "partial_unexpected_counts": [],
#     "partial_unexpected_index_list": []
#   },
#   "meta": {},
#   "expectation_config": {
#     "meta": {},
#     "type": "expect_column_values_to_be_unique",
#     "kwargs": {
#       "batch_id": "pandas-pd dataframe asset",
#       "column": "user_id"
#     }
#   },
#   "success": true,
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# Success!

# %%
### Missing Value check:

users_df_no_duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 212 entries, 0 to 475
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   active               212 non-null    bool
#  1   role                 212 non-null    object
#  2   signUpSource         207 non-null    object
#  3   state                206 non-null    object
#  4   user_id              212 non-null    object
#  5   created_date_time    212 non-null    object
#  6   lastLogin_date_time  172 non-null    object
# dtypes: bool(1), object(6)
# memory usage: 11.8+ KB

# %%
##signup source null check:

users_df_no_duplicates[users_df_no_duplicates['signUpSource'].isna()]
# Out:
#      active         role signUpSource state                   user_id  \
# 388    True     consumer          NaN    WI  55308179e4b0eabd8f99caa2
# 395    True  fetch-staff          NaN    WI  59c124bae4b0299e55b0f330
# 422    True     consumer          NaN   NaN  5a43c08fe4b014fd6b6a0612
# 462    True  fetch-staff          NaN    IL  5964eb07e4b03efd0c0f267b
# 475    True  fetch-staff          NaN   NaN  54943462e4b07e684157a532
#
#            created_date_time      lastLogin_date_time
# 388  2015-04-16 22:43:53.186  2018-05-07 12:23:40.003
# 395  2017-09-19 09:07:54.302  2021-02-08 10:42:58.117
# 422  2017-12-27 09:47:27.059  2021-02-12 10:22:37.155
# 462  2017-07-11 10:13:11.771  2021-03-04 13:07:49.770
# 475  2014-12-19 08:21:22.381  2021-03-05 10:52:23.204

# %%
users_df_no_duplicates['signUpSource'].unique()
# Out:
# array(['Email', 'Google', nan], dtype=object)

# %%
users_df_no_duplicates[users_df_no_duplicates['role'] == 'fetch-staff']
# Out:
#      active         role signUpSource state                   user_id  \
# 395    True  fetch-staff          NaN    WI  59c124bae4b0299e55b0f330
# 408    True  fetch-staff        Email    WI  5f2068904928021530f8fc34
# 432    True  fetch-staff        Email   NaN  5fbc35711d967d1222cbfefc
# 435    True  fetch-staff        Email    NH  5fc961c3b8cfca11a077dd33
# 455    True  fetch-staff        Email   NaN  5fa41775898c7a11a6bcef3e
# 456    True  fetch-staff       Google    AL  5fa32b4d898c7a11a6bcebce
# 462    True  fetch-staff          NaN    IL  5964eb07e4b03efd0c0f267b
# 475    True  fetch-staff          NaN   NaN  54943462e4b07e684157a532
#
#            created_date_time      lastLogin_date_time
# 395  2017-09-19 09:07:54.302  2021-02-08 10:42:58.117
# 408  2020-07-28 13:04:00.905  2021-02-04 09:30:05.375
# 432  2020-11-23 16:19:29.509  2021-02-25 22:25:51.057
# 435  2020-12-03 16:08:03.936  2021-02-26 16:39:16.799
# 455  2020-11-05 09:17:09.396  2021-03-04 10:02:02.026
# 456  2020-11-04 16:29:33.309  2021-03-04 01:21:58.047
# 462  2017-07-11 10:13:11.771  2021-03-04 13:07:49.770
# 475  2014-12-19 08:21:22.381  2021-03-05 10:52:23.204

# %% [markdown]
# The unique values for signup source are Email and Google. It is very miuch possible that fetch-staff can signUp using an internal source which is not email or google. For better data quality, a signupsource exclusively for staff members can be alloted.

# %% [markdown]
# ### Checking the Missing State.
# And also checking if the states are valid.

# %%
users_df_no_duplicates[users_df_no_duplicates['state'].isna()]
# Out:
#      active         role signUpSource state                   user_id  \
# 344    True     consumer        Email   NaN  60145ff384231211ce796d51
# 375    True     consumer        Email   NaN  60186237c8b50e11d8454d5f
# 422    True     consumer          NaN   NaN  5a43c08fe4b014fd6b6a0612
# 432    True  fetch-staff        Email   NaN  5fbc35711d967d1222cbfefc
# 455    True  fetch-staff        Email   NaN  5fa41775898c7a11a6bcef3e
# 475    True  fetch-staff          NaN   NaN  54943462e4b07e684157a532
#
#            created_date_time      lastLogin_date_time
# 344  2021-01-29 13:20:19.722                      NaN
# 375  2021-02-01 14:19:03.551                      NaN
# 422  2017-12-27 09:47:27.059  2021-02-12 10:22:37.155
# 432  2020-11-23 16:19:29.509  2021-02-25 22:25:51.057
# 455  2020-11-05 09:17:09.396  2021-03-04 10:02:02.026
# 475  2014-12-19 08:21:22.381  2021-03-05 10:52:23.204

# %%
sorted(users_df_no_duplicates[~users_df_no_duplicates['state'].isna()]['state'].unique())
# Out:
# ['AL', 'CO', 'IL', 'KY', 'NH', 'OH', 'SC', 'WI']

# %% [markdown]
# From basic research, I understand thay Fetch rewards also has customers from puerto Rico, So it could be that NaN values might correspond to Puerto Rico. Again this is not a significant data Quality issue

# %%
missing_last_login = users_df_no_duplicates[users_df_no_duplicates['lastLogin_date_time'].isna()]

# %%
missing_last_login.groupby('signUpSource').agg({'signUpSource':'size'}).rename(columns = {'signUpSource':'count'}).sort_values(by = 'count',ascending= False)*100/(missing_last_login.shape[0])
# Out:
#               count
# signUpSource
# Email          95.0
# Google          5.0

# %% [markdown]
# Digging deep, it looks like, for all the lsat login date going missing, 95% of them are from email. This appears to be a bottle neck in the email signing up procedure where the users are not allowed to login immediately.

# %%
##Checking if last login date is after creation date

users_df_no_duplicates[users_df_no_duplicates['lastLogin_date_time'] < users_df_no_duplicates['created_date_time']]
# Out:
# Empty DataFrame
# Columns: [active, role, signUpSource, state, user_id, created_date_time, lastLogin_date_time]
# Index: []

# %%
users_df_no_duplicates.groupby('role').agg({'role':'size'}).rename(columns = {'role':'count'}).sort_values(by = 'count',ascending= False)*100/(users_df_no_duplicates.shape[0])
# Out:
#                  count
# role
# consumer     96.226415
# fetch-staff   3.773585

# %% [markdown]
# Summary of users_df Data Quality checks:
#
# 1) Duplicates of data points exists. (Solution - to be removed).
# 2) Missing Values in SignUpSource. (probably missing due to sources that are not email or google (example: Internal for fetch-staff))
# 3) Missing State values (Probably due to Fetch International like Puerto Rico)
# 4) Missing Last_login_date (Noticed out of missing last_login_date, 95% of them are from Email, this appears to be a bottleneck where Email might not allow direct login after the account creation)
# 5) It is mentioned in the schema that the default value for 'role' column is 'consumer' which is not the case since 3.7% of the accounts are fetch-staff's

# %% [markdown]
# ### Brands Data Quality issues

# %%
brands_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1167 entries, 0 to 1166
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   barcode       1167 non-null   int64
#  1   category      1012 non-null   object
#  2   categoryCode  517 non-null    object
#  3   name          1167 non-null   object
#  4   topBrand      555 non-null    object
#  5   brand_id      1167 non-null   object
#  6   cpg_id        1167 non-null   object
#  7   cpg_ref       1167 non-null   object
#  8   brandCode     898 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 82.2+ KB

# %%
### To quantify the above impact even deeper:

duplicate_count_brand_df = brands_df.groupby(list(brands_df.columns)).size().reset_index(name='count').sort_values(by='count', ascending=False)
duplicate_count_brand_df[duplicate_count_brand_df['count']>1].head()
# Out:
# Empty DataFrame
# Columns: [barcode, category, categoryCode, name, topBrand, brand_id, cpg_id, cpg_ref, brandCode, count]
# Index: []

# %%
## Unique test:

context = ge.get_context()
data_source = context.data_sources.add_pandas("pandas")
data_asset = data_source.add_dataframe_asset(name="pd dataframe asset")

batch_definition = data_asset.add_batch_definition_whole_dataframe("batch definition")
batch = batch_definition.get_batch(batch_parameters={"dataframe": brands_df})

#expect user_id to exist:
unique_brand_expectation = ge.expectations.ExpectColumnValuesToBeUnique(column = 'brand_id')
validation_result = batch.validate(unique_brand_expectation)
print(validation_result)
# Out:
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# {
#   "result": {
#     "element_count": 1167,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0,
#     "partial_unexpected_counts": [],
#     "partial_unexpected_index_list": []
#   },
#   "meta": {},
#   "expectation_config": {
#     "meta": {},
#     "type": "expect_column_values_to_be_unique",
#     "kwargs": {
#       "batch_id": "pandas-pd dataframe asset",
#       "column": "brand_id"
#     }
#   },
#   "success": true,
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# ## Every brand ID is unique!!!

# %%
##Checking if brand name and brand code go in synch

brands_df.groupby('name').agg({'brandCode':'size'}).sort_values(by = 'brandCode',ascending= False)
# Out:
#                            brandCode
# name
# ONE A DAY® WOMENS                  2
# Sierra Mist                        2
# Caleb's Kola                       2
# Health Magazine                    2
# Huggies                            2
# ...                              ...
# LOVE HOME AND PLANET               1
# Lance                              1
# LandShark                          1
# Late July                          1
# test brand @1613158231643          1
#
# [1156 rows x 1 columns]

# %%
### Checking if brand names are unique?
brand_count = brands_df.groupby('name').size().reset_index(name='count').sort_values(by='count', ascending=False)
brand_count = brand_count[brand_count['count']>1]
brand_count
# Out:
#                                  name  count
# 504                 ONE A DAY® WOMENS      2
# 627                       Sierra Mist      2
# 129                      Caleb's Kola      2
# 313                   Health Magazine      2
# 333                           Huggies      2
# 564                          Pull-Ups      2
# 699                        V8 Hydrate      2
# 223               Dippin Dots® Cereal      2
# 335  I CAN'T BELIEVE IT'S NOT BUTTER!      2
# 215          Diabetic Living Magazine      2
# 73                          Baken-Ets      2

# %% [markdown]
# #### No they are not: Data Quality issue spotted!

# %% [markdown]
# #### For the above brands, checking if the entities are unique are same. (We already established that brand ids are unique.)

# %%
##checking if brand name and brand code have one-one to relationship (which is expected)

inconsistent = brands_df.groupby('name')['brandCode'].nunique().reset_index()
inconsistent = inconsistent[inconsistent['brandCode'] > 1]
inconsistent
# Out:
#                                  name  brandCode
# 73                          Baken-Ets          2
# 129                      Caleb's Kola          2
# 223               Dippin Dots® Cereal          2
# 313                   Health Magazine          2
# 335  I CAN'T BELIEVE IT'S NOT BUTTER!          2
# 504                 ONE A DAY® WOMENS          2
# 564                          Pull-Ups          2

# %% [markdown]
# ### data Quality issue_spotted; understanding how there are one to two relationship:

# %%
brands_df[brands_df['name'].isin(list(brand_count['name']))].sort_values(by = 'name')
# Out:
#            barcode              category            categoryCode  \
# 848   511111701781                Snacks                     NaN
# 574   511111605546                Snacks                     NaN
# 140   511111000518             Beverages                     NaN
# 740   511111004912                Snacks                     NaN
# 1007  511111205227                   NaN                     NaN
# 1006  511111805298             Magazines                     NaN
# 1163  511111706328    Breakfast & Cereal                     NaN
# 1081  511111206330    Breakfast & Cereal                     NaN
# 194   511111605058             Magazines                     NaN
# 596   511111915287             Magazines               MAGAZINES
# 1074  511111707202                  Baby                    BABY
# 628   511111704652                  Baby                     NaN
# 846   511111314097  Dairy & Refrigerated  DAIRY_AND_REFRIGERATED
# 176   511111700814                 Dairy                     NaN
# 339   511111914051     Health & Wellness                     NaN
# 64    511111805854     Health & Wellness                     NaN
# 978   511111312949                  Baby                     NaN
# 126   511111104698                  Baby                     NaN
# 282   511111903901                   NaN                     NaN
# 1116  511111205500             Beverages                     NaN
# 477   511111304616             Beverages                     NaN
# 1025  511111804604             Beverages                     NaN
#
#                                   name topBrand                  brand_id  \
# 848                          Baken-Ets     True  585a961fe4b03e62d1ce0e76
# 574                          Baken-Ets      NaN  5d9d08d1a60b87376833e348
# 140                       Caleb's Kola    False  5a4d23dae4b0bcb2c74ea77e
# 740                       Caleb's Kola      NaN  5d601d74a3a018514994f422
# 1007          Diabetic Living Magazine      NaN  5d658ffa6d5f3b23d1bc7914
# 1006          Diabetic Living Magazine      NaN  5d66d597a3a018093ab34726
# 1163               Dippin Dots® Cereal      NaN  5dc1fca91dda2c0ad7da64ae
# 1081               Dippin Dots® Cereal      NaN  5dc2d9d4a60b873d6b0666d2
# 194                    Health Magazine      NaN  5d6415d5a3a018514994f429
# 596                    Health Magazine      NaN  5f298852be37ce7958c5952d
# 1074                           Huggies     True  5c7d9cb395144c337a3cbfbb
# 628                            Huggies    False  5bd2011f90fa074576779a17
# 846   I CAN'T BELIEVE IT'S NOT BUTTER!      NaN  5e710dd5ee7f2d0b35b2a193
# 176   I CAN'T BELIEVE IT'S NOT BUTTER!      NaN  592486bee410d61fcea3d12d
# 339                  ONE A DAY® WOMENS      NaN  5e5ff265ee7f2d0b35b2a18f
# 64                   ONE A DAY® WOMENS    False  5da609991dda2c3e1416ae90
# 978                           Pull-Ups     True  5db3288aee7f2d6de4248977
# 126                           Pull-Ups    False  5bd201a990fa074576779a19
# 282                        Sierra Mist      NaN  5332f608e4b03c9a25efd0c1
# 1116                       Sierra Mist      NaN  5d66e07da3a018093ab3472d
# 477                         V8 Hydrate      NaN  5bcdfc5a965c7d66d92731e9
# 1025                        V8 Hydrate    False  5bcdfc5990fa074576779a15
#
#                         cpg_id cpg_ref                         brandCode
# 848   5332f5fbe4b03c9a25efd0ba    Cogs                         BAKEN-ETS
# 574   5332f5fbe4b03c9a25efd0ba    Cogs                         BAKEN ETS
# 140   5332f5fbe4b03c9a25efd0ba    Cogs                      CALEB'S KOLA
# 740   53e10d6368abd3c7065097cc    Cogs                       CALEBS KOLA
# 1007  53e10d6368abd3c7065097cc    Cogs                               NaN
# 1006  5d5d4fd16d5f3b23d1bc7905    Cogs                      511111805298
# 1163  53e10d6368abd3c7065097cc    Cogs                DIPPIN DOTS CEREAL
# 1081  5332f5f3e4b03c9a25efd0ae    Cogs                       DIPPIN DOTS
# 194   5d5d4fd16d5f3b23d1bc7905    Cogs                      511111605058
# 596   5d66b9dcee7f2d201c7281cd    Cogs                            HEALTH
# 1074  5459429be4b0bfcb1e864082    Cogs                           HUGGIES
# 628   550b2565e4b001d5e9e4146f    Cogs                           HUGGIES
# 846   5e5ea9cc9c50da1291a6d074    Cogs   I CAN'T BELIEVE IT'S NOT BUTTER
# 176   53e10d6368abd3c7065097cc    Cogs  I CAN'T BELIEVE IT'S NOT BUTTER!
# 339   53e10d6368abd3c7065097cc    Cogs                 ONE A DAY® WOMENS
# 64    53e10d6368abd3c7065097cc    Cogs                      511111805854
# 978   550b2565e4b001d5e9e4146f    Cogs                           PULLUPS
# 126   550b2565e4b001d5e9e4146f    Cogs                          PULL UPS
# 282   53e10d6368abd3c7065097cc    Cpgs                               NaN
# 1116  5332f5fbe4b03c9a25efd0ba    Cogs                       SIERRA MIST
# 477   53e10d6368abd3c7065097cc    Cogs                               NaN
# 1025  5a734034e4b0d58f376be874    Cogs                        V8 HYDRATE

# %% [markdown]
# #### Some discrepancies can be noticed between brand names and brand codes. Like for example: 'BAKEN-ETS' and 'BAKEN ETS'; 'CALEB'S KOLA' and 'CALEBS KOLA'. This causes a serious problem when trying to understand how well the brands are performing. This issue needs to be resolved for better data quality in Brands. The data entry needs to be done in a consistent way.

# %%
## Checking for missing values

brands_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1167 entries, 0 to 1166
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   barcode       1167 non-null   int64
#  1   category      1012 non-null   object
#  2   categoryCode  517 non-null    object
#  3   name          1167 non-null   object
#  4   topBrand      555 non-null    object
#  5   brand_id      1167 non-null   object
#  6   cpg_id        1167 non-null   object
#  7   cpg_ref       1167 non-null   object
#  8   brandCode     898 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 82.2+ KB

# %%
brands_df['category'].unique()
# Out:
# array(['Baking', 'Beverages', 'Candy & Sweets', 'Condiments & Sauces',
#        'Canned Goods & Soups', nan, 'Magazines', 'Breakfast & Cereal',
#        'Beer Wine Spirits', 'Health & Wellness', 'Beauty', 'Baby',
#        'Frozen', 'Grocery', 'Snacks', 'Household', 'Personal Care',
#        'Dairy', 'Cleaning & Home Improvement', 'Deli',
#        'Beauty & Personal Care', 'Bread & Bakery', 'Outdoor',
#        'Dairy & Refrigerated'], dtype=object)

# %%
#Analyzing missing category

brands_df[brands_df['category'].isna()]
# Out:
#            barcode category categoryCode                  name topBrand  \
# 11    511111102540      NaN          NaN           MorningStar      NaN
# 23    511111303947      NaN          NaN     Bottled Starbucks      NaN
# 24    511111802914      NaN          NaN         Full Throttle      NaN
# 34    511111103653      NaN          NaN            Gold Medal      NaN
# 43    511111503699      NaN          NaN  Glaceau vitaminwater      NaN
# ...            ...      ...          ...                   ...      ...
# 1123  511111403562      NaN          NaN             Bud Light      NaN
# 1135  511111405184      NaN          NaN        Do It Yourself      NaN
# 1144  511111202516      NaN          NaN                Corona      NaN
# 1146  511111703105      NaN          NaN            Bellatoria      NaN
# 1157  511111303015      NaN          NaN                DASANI      NaN
#
#                       brand_id                    cpg_id cpg_ref brandCode
# 11    57c08106e4b0718ff5fcb02c  5332f5f2e4b03c9a25efd0aa    Cpgs       NaN
# 23    5332f5fee4b03c9a25efd0bd  53e10d6368abd3c7065097cc    Cpgs       NaN
# 24    5332fa7ce4b03c9a25efd22e  5332f5ebe4b03c9a25efd0a8    Cpgs       NaN
# 34    5332f772e4b03c9a25efd125  5332f5f3e4b03c9a25efd0ae    Cpgs       NaN
# 43    5332f765e4b03c9a25efd11f  5332f5ebe4b03c9a25efd0a8    Cpgs       NaN
# ...                        ...                       ...     ...       ...
# 1123  5332f7a8e4b03c9a25efd135  5332f7a7e4b03c9a25efd134    Cpgs       NaN
# 1135  5d658fca6d5f3b23d1bc7912  53e10d6368abd3c7065097cc    Cogs       NaN
# 1144  57c08242e4b0718ff5fcb032  5332f7a7e4b03c9a25efd134    Cpgs       NaN
# 1146  5332fa12e4b03c9a25efd1e6  5332fa12e4b03c9a25efd1e7    Cpgs       NaN
# 1157  5332fa75e4b03c9a25efd221  5332f5ebe4b03c9a25efd0a8    Cpgs       NaN
#
# [155 rows x 9 columns]

# %% [markdown]
# ### Data Issue spotted!
#
# For missing category values, I can observe that the mapping of brands to category has been incomplete. For example, brands like Bud Light, Corona etc can be mapped to 'Beers & Wine Spirits'. This Data quality issue needs to be resolved to better understand how each category is performing. The solution could be going back to the data entry source and making sure that the category is entered correctly. If the category is not present, then it makes sense to leave it blank.
#
# This also gives an idea of creating a new table (entity) dedicated to categories. Whenever a new category comes, the table can be updated and the brands table and category table could be linked by category_id

# %%
### Checking if Category values have a unique pair of category code
### checking inconsistent

inconsistent = brands_df.groupby('category')['categoryCode'].nunique().reset_index()
inconsistent = inconsistent[inconsistent['categoryCode'] > 1]
inconsistent
# Out:
# Empty DataFrame
# Columns: [category, categoryCode]
# Index: []

# %% [markdown]
# category and category Code maintain one-one relationships for non-missing values

# %%
brands_df[(~brands_df['category'].isna()) & (brands_df['categoryCode'].isna())].head()
# Out:
#          barcode              category categoryCode                   name  \
# 7   511111104810   Condiments & Sauces          NaN             J.L. Kraft
# 8   511111504412  Canned Goods & Soups          NaN  Campbell's Home Style
# 9   511111504788                Baking          NaN                   test
# 12  511111201076                Baking          NaN                Calumet
# 13  511111205012             Magazines          NaN   Entertainment Weekly
#
#    topBrand                  brand_id                    cpg_id cpg_ref  \
# 7       NaN  5cdad0f5166eb33eb7ce0faa  559c2234e4b06aca36af13c6    Cogs
# 8     False  5ab15636e4b0be0a89bb0b07  5a734034e4b0d58f376be874    Cogs
# 9       NaN  5c408e8bcd244a1fdb47aee7  59ba6f1ce4b092b29c167346    Cogs
# 12    False  588ba07be4b02187f85cdadd  559c2234e4b06aca36af13c6    Cogs
# 13      NaN  5d6413156d5f3b23d1bc790a  5d5d4fd16d5f3b23d1bc7905    Cogs
#
#                brandCode
# 7             J.L. KRAFT
# 8   CAMPBELLS HOME STYLE
# 9                   TEST
# 12               CALUMET
# 13          511111205012

# %% [markdown]
# ### Data Quality Issue spotted!

# %% [markdown]
# The data entry/ qulaity should be in such a way that each category, categoryCode should be filled automatically

# %%
brands_df[(brands_df['category'].isna()) & (brands_df['categoryCode'].isna())]
# Out:
#            barcode category categoryCode                  name topBrand  \
# 11    511111102540      NaN          NaN           MorningStar      NaN
# 23    511111303947      NaN          NaN     Bottled Starbucks      NaN
# 24    511111802914      NaN          NaN         Full Throttle      NaN
# 34    511111103653      NaN          NaN            Gold Medal      NaN
# 43    511111503699      NaN          NaN  Glaceau vitaminwater      NaN
# ...            ...      ...          ...                   ...      ...
# 1123  511111403562      NaN          NaN             Bud Light      NaN
# 1135  511111405184      NaN          NaN        Do It Yourself      NaN
# 1144  511111202516      NaN          NaN                Corona      NaN
# 1146  511111703105      NaN          NaN            Bellatoria      NaN
# 1157  511111303015      NaN          NaN                DASANI      NaN
#
#                       brand_id                    cpg_id cpg_ref brandCode
# 11    57c08106e4b0718ff5fcb02c  5332f5f2e4b03c9a25efd0aa    Cpgs       NaN
# 23    5332f5fee4b03c9a25efd0bd  53e10d6368abd3c7065097cc    Cpgs       NaN
# 24    5332fa7ce4b03c9a25efd22e  5332f5ebe4b03c9a25efd0a8    Cpgs       NaN
# 34    5332f772e4b03c9a25efd125  5332f5f3e4b03c9a25efd0ae    Cpgs       NaN
# 43    5332f765e4b03c9a25efd11f  5332f5ebe4b03c9a25efd0a8    Cpgs       NaN
# ...                        ...                       ...     ...       ...
# 1123  5332f7a8e4b03c9a25efd135  5332f7a7e4b03c9a25efd134    Cpgs       NaN
# 1135  5d658fca6d5f3b23d1bc7912  53e10d6368abd3c7065097cc    Cogs       NaN
# 1144  57c08242e4b0718ff5fcb032  5332f7a7e4b03c9a25efd134    Cpgs       NaN
# 1146  5332fa12e4b03c9a25efd1e6  5332fa12e4b03c9a25efd1e7    Cpgs       NaN
# 1157  5332fa75e4b03c9a25efd221  5332f5ebe4b03c9a25efd0a8    Cpgs       NaN
#
# [155 rows x 9 columns]

# %%
## Missing brandCode:

brands_df[brands_df['brandCode'].isna()]

## It should be made sure that brand name and brand code maintain a one-one relationship as well. Once the brand name is entered, appropriate brandcode should be filled.
# Out:
#            barcode   category categoryCode                       name  \
# 0     511111019862     Baking       BAKING  test brand @1612366101024
# 11    511111102540        NaN          NaN                MorningStar
# 18    511111317364     Baking       BAKING  test brand @1605535049181
# 23    511111303947        NaN          NaN          Bottled Starbucks
# 24    511111802914        NaN          NaN              Full Throttle
# ...            ...        ...          ...                        ...
# 1144  511111202516        NaN          NaN                     Corona
# 1146  511111703105        NaN          NaN                 Bellatoria
# 1157  511111303015        NaN          NaN                     DASANI
# 1159  511111501619  Beverages          NaN                  Pepsi Max
# 1162  511111116752     Baking       BAKING  test brand @1601644365844
#
#      topBrand                  brand_id                    cpg_id cpg_ref  \
# 0       False  601ac115be37ce2ead437551  601ac114be37ce2ead437550    Cogs
# 11        NaN  57c08106e4b0718ff5fcb02c  5332f5f2e4b03c9a25efd0aa    Cpgs
# 18      False  5fb28549be37ce522e165cb5  5fb28549be37ce522e165cb4    Cogs
# 23        NaN  5332f5fee4b03c9a25efd0bd  53e10d6368abd3c7065097cc    Cpgs
# 24        NaN  5332fa7ce4b03c9a25efd22e  5332f5ebe4b03c9a25efd0a8    Cpgs
# ...       ...                       ...                       ...     ...
# 1144      NaN  57c08242e4b0718ff5fcb032  5332f7a7e4b03c9a25efd134    Cpgs
# 1146      NaN  5332fa12e4b03c9a25efd1e6  5332fa12e4b03c9a25efd1e7    Cpgs
# 1157      NaN  5332fa75e4b03c9a25efd221  5332f5ebe4b03c9a25efd0a8    Cpgs
# 1159    False  585a96cbe4b03e62d1ce0e88  5332f5fbe4b03c9a25efd0ba    Cogs
# 1162      NaN  5f77274dbe37ce6b592e90c0  5f77274dbe37ce6b592e90bf    Cogs
#
#      brandCode
# 0          NaN
# 11         NaN
# 18         NaN
# 23         NaN
# 24         NaN
# ...        ...
# 1144       NaN
# 1146       NaN
# 1157       NaN
# 1159       NaN
# 1162       NaN
#
# [269 rows x 9 columns]

# %% [markdown]
# ### Missing values in TopBrand
#
# This is not necessarily a data quality problem since, 'topBrand' could be subjective. But if there is classification that is useful for business. I woud suggest that we incorporate the 'time' factor into the column 'topBrand' since any Brand can become top in future, or the current topbrands might not be top, so there is a  need for version table or a history table which contians columns brand_id,TopBrand, time

# %% [markdown]
# #### Receipts Data Quality issues:

# %%
receipts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1119 entries, 0 to 1118
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   bonusPointsEarned        544 non-null    float64
#  1   bonusPointsEarnedReason  544 non-null    object
#  2   pointsEarned             609 non-null    float64
#  3   purchasedItemCount       635 non-null    float64
#  4   rewardsReceiptItemList   679 non-null    object
#  5   rewardsReceiptStatus     1119 non-null   object
#  6   totalSpent               684 non-null    float64
#  7   userId                   1119 non-null   object
#  8   receipt_id               1119 non-null   object
#  9   created_date_time        1119 non-null   object
#  10  scanned_date_time        1119 non-null   object
#  11  finished_date_time       568 non-null    object
#  12  modify_date_time         1119 non-null   object
#  13  pointsAwarded_date_time  537 non-null    object
#  14  purchased_date_time      671 non-null    object
# dtypes: float64(4), object(11)
# memory usage: 131.3+ KB

# %%
## Unique test:

context = ge.get_context()
data_source = context.data_sources.add_pandas("pandas")
data_asset = data_source.add_dataframe_asset(name="pd dataframe asset")

batch_definition = data_asset.add_batch_definition_whole_dataframe("batch definition")
batch = batch_definition.get_batch(batch_parameters={"dataframe": receipts_df})

#expect user_id to exist:
unique_receipt_expectation = ge.expectations.ExpectColumnValuesToBeUnique(column = 'receipt_id')
validation_result = batch.validate(unique_receipt_expectation)
print(validation_result)
# Out:
# Calculating Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# {
#   "result": {
#     "element_count": 1119,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0,
#     "partial_unexpected_counts": [],
#     "partial_unexpected_index_list": []
#   },
#   "meta": {},
#   "expectation_config": {
#     "meta": {},
#     "type": "expect_column_values_to_be_unique",
#     "kwargs": {
#       "batch_id": "pandas-pd dataframe asset",
#       "column": "receipt_id"
#     }
#   },
#   "success": true,
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
receipts_df.head()
# Out:
#    bonusPointsEarned                            bonusPointsEarnedReason  \
# 0              500.0  Receipt number 2 completed, bonus point schedu...
# 1              150.0  Receipt number 5 completed, bonus point schedu...
# 2                5.0                         All-receipts receipt bonus
# 3                5.0                         All-receipts receipt bonus
# 4                5.0                         All-receipts receipt bonus
#
#    pointsEarned  purchasedItemCount  \
# 0         500.0                 5.0
# 1         150.0                 2.0
# 2           5.0                 1.0
# 3           5.0                 4.0
# 4           5.0                 2.0
#
#                               rewardsReceiptItemList rewardsReceiptStatus  \
# 0  [{'barcode': '4011', 'description': 'ITEM NOT ...             FINISHED
# 1  [{'barcode': '4011', 'description': 'ITEM NOT ...             FINISHED
# 2  [{'needsFetchReview': False, 'partnerItemId': ...             REJECTED
# 3  [{'barcode': '4011', 'description': 'ITEM NOT ...             FINISHED
# 4  [{'barcode': '4011', 'description': 'ITEM NOT ...             FINISHED
#
#    totalSpent                    userId                receipt_id  \
# 0        26.0  5ff1e1eacfcf6c399c274ae6  5ff1e1eb0a720f0523000575
# 1        11.0  5ff1e194b6a9d73a3a9f1052  5ff1e1bb0a720f052300056b
# 2        10.0  5ff1e1f1cfcf6c399c274b0b  5ff1e1f10a720f052300057a
# 3        28.0  5ff1e1eacfcf6c399c274ae6  5ff1e1ee0a7214ada100056f
# 4         1.0  5ff1e194b6a9d73a3a9f1052  5ff1e1d20a7214ada1000561
#
#          created_date_time        scanned_date_time       finished_date_time  \
# 0  2021-01-03 09:25:31.000  2021-01-03 09:25:31.000  2021-01-03 09:25:31.000
# 1  2021-01-03 09:24:43.000  2021-01-03 09:24:43.000  2021-01-03 09:24:43.000
# 2  2021-01-03 09:25:37.000  2021-01-03 09:25:37.000                      NaN
# 3  2021-01-03 09:25:34.000  2021-01-03 09:25:34.000  2021-01-03 09:25:34.000
# 4  2021-01-03 09:25:06.000  2021-01-03 09:25:06.000  2021-01-03 09:25:11.000
#
#           modify_date_time pointsAwarded_date_time  purchased_date_time
# 0  2021-01-03 09:25:36.000     2021-01-03 09:25:31  2021-01-02 18:00:00
# 1  2021-01-03 09:24:48.000     2021-01-03 09:24:43  2021-01-02 09:24:43
# 2  2021-01-03 09:25:42.000                     NaN  2021-01-02 18:00:00
# 3  2021-01-03 09:25:39.000     2021-01-03 09:25:34  2021-01-02 18:00:00
# 4  2021-01-03 09:25:11.000     2021-01-03 09:25:06  2021-01-02 09:25:06

# %% [markdown]
# ### understanding bonuspoints missing values

# %%
receipts_df[receipts_df['bonusPointsEarned'].isna()].head()
# Out:
#     bonusPointsEarned bonusPointsEarnedReason  pointsEarned  \
# 15                NaN                     NaN           NaN
# 28                NaN                     NaN           NaN
# 32                NaN                     NaN         500.0
# 35                NaN                     NaN         250.0
# 52                NaN                     NaN         350.0
#
#     purchasedItemCount                             rewardsReceiptItemList  \
# 15                 0.0  [{'needsFetchReview': True, 'needsFetchReviewR...
# 28                 3.0  [{'deleted': True, 'description': 'DELETED ITE...
# 32                 9.0  [{'barcode': '029000079236', 'description': 'P...
# 35                 5.0  [{'barcode': '044700009888', 'description': 'O...
# 52                 1.0  [{'barcode': '044700019917', 'description': 'O...
#
#    rewardsReceiptStatus  totalSpent                    userId  \
# 15              FLAGGED        0.00  5ff1e1e9b6a9d73a3a9f10f6
# 28             REJECTED        3.00  5ff1e194b6a9d73a3a9f1052
# 32             FINISHED       89.91  5ff36be7135e7011bcb856d3
# 35             FINISHED       49.95  5ff36a3862fde912123a4460
# 52             FINISHED       10.00  5ff370c562fde912123a5e0e
#
#                   receipt_id        created_date_time  \
# 15  5ff1e1e90a7214ada1000569  2021-01-03 09:25:29.000
# 28  5ff1e1d40a7214ada1000562  2021-01-03 09:25:08.000
# 32  5ff36c750a7214ada100058f  2021-01-04 13:28:53.000
# 35  5ff36adb0a720f0523000590  2021-01-04 13:22:03.000
# 52  5ff3713c0a7214ada10005b6  2021-01-04 13:49:16.000
#
#           scanned_date_time       finished_date_time         modify_date_time  \
# 15  2021-01-03 09:25:29.000                      NaN  2021-01-03 09:25:29.000
# 28  2021-01-03 09:25:08.000                      NaN  2021-01-03 09:25:08.000
# 32  2021-01-04 13:28:53.000  2021-01-04 13:28:54.000  2021-01-04 13:28:54.000
# 35  2021-01-04 13:22:03.000  2021-01-04 13:22:04.000  2021-01-04 13:22:04.000
# 52  2021-01-04 13:49:16.000  2021-01-04 13:49:16.000  2021-01-04 13:49:16.000
#
#    pointsAwarded_date_time  purchased_date_time
# 15                     NaN                  NaN
# 28                     NaN  2017-10-29 19:00:00
# 32     2021-01-04 13:28:54  2021-01-03 13:28:53
# 35     2021-01-04 13:22:04  2020-12-30 00:00:00
# 52     2021-01-04 13:49:16  2021-01-03 13:49:16

# %% [markdown]
# ### Understanding missing points earned

# %%
missing_points_df = receipts_df[receipts_df['pointsEarned'].isna()]

# %% [markdown]
# missing values in bonuspoints earned could be imputed with 0 and bonus points earned reason can be filled with bonus points not awarded

# %%
missing_points_percent_count = missing_points_df\
    .groupby('rewardsReceiptStatus').agg({'rewardsReceiptStatus':'size'})\
    .rename(columns = {'rewardsReceiptStatus':'count'})\
    .sort_values(by = 'count',ascending = False)*100/missing_points_df.shape[0]
missing_points_percent_count
# Out:
#                           count
# rewardsReceiptStatus
# SUBMITTED             85.098039
# PENDING                9.803922
# FLAGGED                2.549020
# REJECTED               2.549020

# %% [markdown]
# #### It can be observed that for the points that are missing, 96% of them are submitted,pending,flagged and awaiting points; while other categories like rejected; it can be automatically filled with 0 - a mild not a very serious data quality issue

# %%
##Checking rewards item list that are empty

missing_items = receipts_df[receipts_df['rewardsReceiptItemList'].isna()]
missing_items.head()
# Out:
#      bonusPointsEarned bonusPointsEarnedReason  pointsEarned  \
# 71                 NaN                     NaN           NaN
# 93                 NaN                     NaN           NaN
# 149                NaN                     NaN           NaN
# 175                NaN                     NaN           NaN
# 212                NaN                     NaN           NaN
#
#      purchasedItemCount rewardsReceiptItemList rewardsReceiptStatus  \
# 71                  NaN                    NaN            SUBMITTED
# 93                  NaN                    NaN            SUBMITTED
# 149                 NaN                    NaN            SUBMITTED
# 175                 0.0                    NaN             REJECTED
# 212                 NaN                    NaN            SUBMITTED
#
#      totalSpent                    userId                receipt_id  \
# 71          NaN  5a43c08fe4b014fd6b6a0612  5ff475820a7214ada10005cf
# 93          NaN  5a43c08fe4b014fd6b6a0612  5ff5ecb90a7214ada10005f9
# 149         NaN  5ff7264e8f142f11dd189504  5ff726860a720f05230005ec
# 175         0.0  5ff8da28b3348b11c9337ac6  5ff8da570a720f05c5000015
# 212         NaN  59c124bae4b0299e55b0f330  5ffce8570a7214ad4e003e6f
#
#            created_date_time        scanned_date_time finished_date_time  \
# 71   2021-01-05 08:19:46.000  2021-01-05 08:19:46.000                NaN
# 93   2021-01-06 11:00:40.000  2021-01-06 11:00:40.000                NaN
# 149  2021-01-07 09:19:34.000  2021-01-07 09:19:34.000                NaN
# 175  2021-01-08 16:19:03.000  2021-01-08 16:19:03.000                NaN
# 212  2021-01-11 18:07:51.000  2021-01-11 18:07:51.000                NaN
#
#             modify_date_time pointsAwarded_date_time purchased_date_time
# 71   2021-01-05 08:19:46.000                     NaN                 NaN
# 93   2021-01-06 11:00:40.000                     NaN                 NaN
# 149  2021-01-07 09:19:34.000                     NaN                 NaN
# 175  2021-01-08 16:19:04.000                     NaN                 NaN
# 212  2021-01-11 18:07:51.000                     NaN                 NaN

# %%
missing_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 440 entries, 71 to 1118
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   bonusPointsEarned        2 non-null      float64
#  1   bonusPointsEarnedReason  2 non-null      object
#  2   pointsEarned             2 non-null      float64
#  3   purchasedItemCount       5 non-null      float64
#  4   rewardsReceiptItemList   0 non-null      object
#  5   rewardsReceiptStatus     440 non-null    object
#  6   totalSpent               5 non-null      float64
#  7   userId                   440 non-null    object
#  8   receipt_id               440 non-null    object
#  9   created_date_time        440 non-null    object
#  10  scanned_date_time        440 non-null    object
#  11  finished_date_time       3 non-null      object
#  12  modify_date_time         440 non-null    object
#  13  pointsAwarded_date_time  2 non-null      object
#  14  purchased_date_time      3 non-null      object
# dtypes: float64(4), object(11)
# memory usage: 55.0+ KB

# %%
missing_items_percent_count = missing_items\
    .groupby('rewardsReceiptStatus').agg({'rewardsReceiptStatus':'size'})\
    .rename(columns = {'rewardsReceiptStatus':'count'})\
    .sort_values(by = 'count',ascending = False)*100/missing_items.shape[0]
missing_items_percent_count
# Out:
#                           count
# rewardsReceiptStatus
# SUBMITTED             98.636364
# REJECTED               0.681818
# FINISHED               0.454545
# PENDING                0.227273

# %% [markdown]
# #### could be the reason where the scanning algorithm couldnt detect the items in the list. So we can conclude that it is not serious big data quality issue. It would have been a serious issue when there is significant contribution from 'finished' status, and from the bottom table, it is shown that bonus points are awarded for some valid reason and hence finished status

# %%
## Checking missing rewards item list:

receipts_df[(receipts_df['rewardsReceiptItemList'].isna()) & (~receipts_df['pointsEarned'].isna())]
# Out:
#      bonusPointsEarned                            bonusPointsEarnedReason  \
# 396              250.0  Receipt number 3 completed, bonus point schedu...
# 424              500.0  Receipt number 2 completed, bonus point schedu...
#
#      pointsEarned  purchasedItemCount rewardsReceiptItemList  \
# 396         250.0                 0.0                    NaN
# 424         500.0                 0.0                    NaN
#
#     rewardsReceiptStatus  totalSpent                    userId  \
# 396             FINISHED         0.0  6009e60450b3311194385009
# 424             FINISHED         0.0  600afb2a7d983a124e9aded0
#
#                    receipt_id        created_date_time  \
# 396  6009eb000a7214ada2000003  2021-01-21 14:58:40.000
# 424  600aff160a720f053500000c  2021-01-22 10:36:38.000
#
#            scanned_date_time       finished_date_time  \
# 396  2021-01-21 14:58:40.000  2021-01-21 14:59:06.000
# 424  2021-01-22 10:36:38.000  2021-01-22 10:37:01.000
#
#             modify_date_time pointsAwarded_date_time  purchased_date_time
# 396  2021-01-21 14:59:15.000     2021-01-21 14:59:06  2021-01-20 18:00:00
# 424  2021-01-22 10:37:13.000     2021-01-22 10:37:01  2021-01-21 18:00:00

# %%
##understanding the potential reasons why purchased_date_time could be missing:

receipts_df[receipts_df['purchased_date_time'].isna()]
# Out:
#       bonusPointsEarned bonusPointsEarnedReason  pointsEarned  \
# 15                  NaN                     NaN           NaN
# 71                  NaN                     NaN           NaN
# 81                  NaN                     NaN           NaN
# 93                  NaN                     NaN           NaN
# 141                 NaN                     NaN           NaN
# ...                 ...                     ...           ...
# 1110                NaN                     NaN           NaN
# 1111                NaN                     NaN           NaN
# 1115                NaN                     NaN           NaN
# 1116                NaN                     NaN           NaN
# 1118                NaN                     NaN           NaN
#
#       purchasedItemCount                             rewardsReceiptItemList  \
# 15                   0.0  [{'needsFetchReview': True, 'needsFetchReviewR...
# 71                   NaN                                                NaN
# 81                   0.0  [{'needsFetchReview': True, 'needsFetchReviewR...
# 93                   NaN                                                NaN
# 141                  0.0  [{'needsFetchReview': True, 'needsFetchReviewR...
# ...                  ...                                                ...
# 1110                 NaN                                                NaN
# 1111                 NaN                                                NaN
# 1115                 NaN                                                NaN
# 1116                 NaN                                                NaN
# 1118                 NaN                                                NaN
#
#      rewardsReceiptStatus  totalSpent                    userId  \
# 15                FLAGGED         0.0  5ff1e1e9b6a9d73a3a9f10f6
# 71              SUBMITTED         NaN  5a43c08fe4b014fd6b6a0612
# 81                FLAGGED         0.0  5ff4ce3cc1e2d0121a9b2fba
# 93              SUBMITTED         NaN  5a43c08fe4b014fd6b6a0612
# 141               FLAGGED         0.0  5ff73be9eb7c7d31ca8a45bc
# ...                   ...         ...                       ...
# 1110            SUBMITTED         NaN  5fc961c3b8cfca11a077dd33
# 1111            SUBMITTED         NaN  5fc961c3b8cfca11a077dd33
# 1115            SUBMITTED         NaN  5fc961c3b8cfca11a077dd33
# 1116            SUBMITTED         NaN  5fc961c3b8cfca11a077dd33
# 1118            SUBMITTED         NaN  5fc961c3b8cfca11a077dd33
#
#                     receipt_id        created_date_time  \
# 15    5ff1e1e90a7214ada1000569  2021-01-03 09:25:29.000
# 71    5ff475820a7214ada10005cf  2021-01-05 08:19:46.000
# 81    5ff4ce3c0a720f05230005c4  2021-01-05 14:38:20.000
# 93    5ff5ecb90a7214ada10005f9  2021-01-06 11:00:40.000
# 141   5ff73be90a720f052300060a  2021-01-07 10:50:49.000
# ...                        ...                      ...
# 1110  603c6adf0a720fde1000039a  2021-02-28 22:17:35.736
# 1111  603c9e6e0a720fde100003c7  2021-03-01 01:57:34.307
# 1115  603d0b710a720fde1000042a  2021-03-01 09:42:41.873
# 1116  603cf5290a720fde10000413  2021-03-01 08:07:37.664
# 1118  603c4fea0a7217c72c000389  2021-02-28 20:22:34.962
#
#             scanned_date_time finished_date_time         modify_date_time  \
# 15    2021-01-03 09:25:29.000                NaN  2021-01-03 09:25:29.000
# 71    2021-01-05 08:19:46.000                NaN  2021-01-05 08:19:46.000
# 81    2021-01-05 14:38:20.000                NaN  2021-01-05 14:38:20.000
# 93    2021-01-06 11:00:40.000                NaN  2021-01-06 11:00:40.000
# 141   2021-01-07 10:50:49.000                NaN  2021-01-07 10:50:49.000
# ...                       ...                ...                      ...
# 1110  2021-02-28 22:17:35.736                NaN  2021-02-28 22:17:35.736
# 1111  2021-03-01 01:57:34.307                NaN  2021-03-01 01:57:34.307
# 1115  2021-03-01 09:42:41.873                NaN  2021-03-01 09:42:41.873
# 1116  2021-03-01 08:07:37.664                NaN  2021-03-01 08:07:37.664
# 1118  2021-02-28 20:22:34.962                NaN  2021-02-28 20:22:34.962
#
#      pointsAwarded_date_time purchased_date_time
# 15                       NaN                 NaN
# 71                       NaN                 NaN
# 81                       NaN                 NaN
# 93                       NaN                 NaN
# 141                      NaN                 NaN
# ...                      ...                 ...
# 1110                     NaN                 NaN
# 1111                     NaN                 NaN
# 1115                     NaN                 NaN
# 1116                     NaN                 NaN
# 1118                     NaN                 NaN
#
# [448 rows x 15 columns]

# %%
### checking if purchase_date is before created_date_time:


receipts_df[receipts_df['purchased_date_time']>receipts_df['scanned_date_time']]
# Out:
#      bonusPointsEarned                            bonusPointsEarnedReason  \
# 12               150.0  Receipt number 5 completed, bonus point schedu...
# 14               300.0  Receipt number 4 completed, bonus point schedu...
# 85                25.0                        COMPLETE_NONPARTNER_RECEIPT
# 139                NaN                                                NaN
# 158              500.0  Receipt number 2 completed, bonus point schedu...
# 190              250.0  Receipt number 3 completed, bonus point schedu...
# 244               25.0                        COMPLETE_NONPARTNER_RECEIPT
# 265                NaN                                                NaN
# 294                NaN                                                NaN
# 362              250.0  Receipt number 3 completed, bonus point schedu...
# 553              750.0  Receipt number 1 completed, bonus point schedu...
# 644              500.0  Receipt number 2 completed, bonus point schedu...
# 871               25.0                        COMPLETE_NONPARTNER_RECEIPT
#
#      pointsEarned  purchasedItemCount  \
# 12         8850.0                10.0
# 14          300.0                 1.0
# 85           25.0                 1.0
# 139        8700.0                10.0
# 158        9200.0                10.0
# 190        8950.0                10.0
# 244          25.0                 1.0
# 265        8700.0                10.0
# 294        8700.0                10.0
# 362         250.0                 1.0
# 553         750.0                 1.0
# 644         500.0                 1.0
# 871          25.0                 1.0
#
#                                 rewardsReceiptItemList rewardsReceiptStatus  \
# 12   [{'barcode': '034100573065', 'description': 'M...              FLAGGED
# 14   [{'barcode': '4011', 'description': 'ITEM NOT ...             FINISHED
# 85   [{'barcode': '4011', 'description': 'ITEM NOT ...             FINISHED
# 139  [{'barcode': '034100573065', 'description': 'M...              FLAGGED
# 158  [{'barcode': '034100573065', 'description': 'M...              FLAGGED
# 190  [{'barcode': '034100573065', 'description': 'M...              FLAGGED
# 244  [{'barcode': '4011', 'description': 'ITEM NOT ...             FINISHED
# 265  [{'barcode': '034100573065', 'description': 'M...              FLAGGED
# 294  [{'barcode': '034100573065', 'description': 'M...              FLAGGED
# 362  [{'barcode': '4011', 'description': 'ITEM NOT ...             FINISHED
# 553  [{'barcode': '4011', 'description': 'ITEM NOT ...             FINISHED
# 644  [{'barcode': '4011', 'description': 'ITEM NOT ...             FINISHED
# 871  [{'barcode': '4011', 'description': 'ITEM NOT ...             FINISHED
#
#      totalSpent                    userId                receipt_id  \
# 12        290.0  5ff1e194b6a9d73a3a9f1052  5ff1e1b60a7214ada100055c
# 14          1.0  5ff1e194b6a9d73a3a9f1052  5ff1e1b20a7214ada100055a
# 85          1.0  5ff4ce33c3d63511e2a484b6  5ff4ce640a7214ada10005e0
# 139       290.0  5ff73b90eb7c7d31ca8a452b  5ff73be10a7214ada1000619
# 158       290.0  5ff873d1b3348b11c9337716  5ff873f10a720f052300064f
# 190       290.0  5ffcb47d04929111f6e9256c  5ffcb4900a720f0515000002
# 244         1.0  5fff2698b3348b03eb45bb10  5fff26ee0a720f05f300001a
# 265       290.0  5fff2698b3348b03eb45bb10  5fff26f10a7214ad4c000018
# 294       290.0  6000d46cfb296c121a81b20c  6000d4bc0a7214ad4c000070
# 362         1.0  6008873eb6310511daa4e8eb  600887560a720f05fa000098
# 553         1.0  60145a3c84231211ce796c5d  60145a3d0a7214ad50000082
# 644         1.0  60182f1dc8b50e11d84548c4  60182f290a720f05f800032f
# 871         1.0  6021768799409b11fcf8987f  602176c90a7214d8e9000028
#
#            created_date_time        scanned_date_time  \
# 12   2021-01-03 09:24:38.000  2021-01-03 09:24:38.000
# 14   2021-01-03 09:24:34.000  2021-01-03 09:24:34.000
# 85   2021-01-05 14:39:00.000  2021-01-05 14:39:00.000
# 139  2021-01-07 10:50:41.000  2021-01-07 10:50:41.000
# 158  2021-01-08 09:02:09.000  2021-01-08 09:02:09.000
# 190  2021-01-11 14:26:56.000  2021-01-11 14:26:56.000
# 244  2021-01-13 10:59:26.000  2021-01-13 10:59:26.000
# 265  2021-01-13 10:59:29.000  2021-01-13 10:59:29.000
# 294  2021-01-14 17:33:16.000  2021-01-14 17:33:16.000
# 362  2021-01-20 13:41:10.000  2021-01-20 13:41:10.000
# 553  2021-01-29 12:55:57.000  2021-01-29 12:55:57.000
# 644  2021-02-01 10:41:13.000  2021-02-01 10:41:13.000
# 871  2021-02-08 11:37:13.000  2021-02-08 11:37:13.000
#
#           finished_date_time         modify_date_time pointsAwarded_date_time  \
# 12                       NaN  2021-01-03 09:24:38.000                     NaN
# 14   2021-01-03 09:24:35.000  2021-01-03 09:24:35.000     2021-01-03 09:24:35
# 85   2021-01-05 14:39:00.000  2021-01-05 14:39:00.000     2021-01-05 14:39:00
# 139                      NaN  2021-01-07 10:50:41.000                     NaN
# 158                      NaN  2021-01-08 09:02:10.000                     NaN
# 190                      NaN  2021-01-11 14:26:57.000                     NaN
# 244  2021-01-13 10:59:26.000  2021-01-13 10:59:26.000     2021-01-13 10:59:26
# 265                      NaN  2021-01-13 10:59:29.000                     NaN
# 294                      NaN  2021-01-14 17:33:17.000                     NaN
# 362  2021-01-20 13:41:11.000  2021-01-20 13:41:11.000     2021-01-20 13:41:11
# 553  2021-01-29 12:56:00.000  2021-01-29 12:56:00.000     2021-01-29 12:56:00
# 644  2021-02-01 10:41:13.000  2021-02-01 10:41:13.000     2021-02-01 10:41:13
# 871  2021-02-08 11:37:13.000  2021-02-08 11:37:13.000     2021-02-08 11:37:13
#
#      purchased_date_time
# 12   2021-02-03 09:24:38
# 14   2021-02-03 09:24:35
# 85   2021-02-05 14:39:00
# 139  2021-02-07 10:50:41
# 158  2021-02-08 09:02:10
# 190  2021-02-11 14:26:56
# 244  2021-02-13 10:59:26
# 265  2021-02-13 10:59:29
# 294  2021-02-14 17:33:17
# 362  2021-02-20 13:41:10
# 553  2021-02-28 12:55:58
# 644  2021-03-01 10:41:13
# 871  2021-03-08 11:37:13

# %% [markdown]
# ### data Quality issue spotted!

# %% [markdown]
# There are some data points whose purchase date is ahead of the receipt created date. As far I understand the business equation, the purchased date should be before the creation/scanned date time. This could be data issue that needs to be flagged.

# %%
### Checking if the all the userids present in the receipt are present in the users_df.

receipts_df[~receipts_df['userId'].isin(users_df_no_duplicates['user_id'])]
# Out:
#      bonusPointsEarned                            bonusPointsEarnedReason  \
# 13               750.0  Receipt number 1 completed, bonus point schedu...
# 15                 NaN                                                NaN
# 16               750.0  Receipt number 1 completed, bonus point schedu...
# 20               300.0  Receipt number 4 completed, bonus point schedu...
# 21               750.0  Receipt number 1 completed, bonus point schedu...
# ..                 ...                                                ...
# 955                5.0                         All-receipts receipt bonus
# 956              500.0  Receipt number 2 completed, bonus point schedu...
# 966                5.0                         All-receipts receipt bonus
# 985              100.0  Receipt number 6 completed, bonus point schedu...
# 990              750.0  Receipt number 1 completed, bonus point schedu...
#
#      pointsEarned  purchasedItemCount  \
# 13          750.0                11.0
# 15            NaN                 0.0
# 16          750.0                 2.0
# 20          389.2                 6.0
# 21          750.0                 1.0
# ..            ...                 ...
# 955           5.0                 1.0
# 956        3500.0                 5.0
# 966           5.0                 2.0
# 985         100.0                 3.0
# 990         850.0                 1.0
#
#                                 rewardsReceiptItemList rewardsReceiptStatus  \
# 13   [{'barcode': '075925306254', 'competitiveProdu...             REJECTED
# 15   [{'needsFetchReview': True, 'needsFetchReviewR...              FLAGGED
# 16   [{'barcode': '4011', 'description': 'ITEM NOT ...             FINISHED
# 20   [{'barcode': '075925306254', 'competitiveProdu...             FINISHED
# 21   [{'barcode': '4011', 'description': 'ITEM NOT ...             FINISHED
# ..                                                 ...                  ...
# 955  [{'brandCode': 'MISSION', 'competitorRewardsGr...             FINISHED
# 956  [{'barcode': '4011', 'description': 'ITEM NOT ...             FINISHED
# 966  [{'barcode': '4011', 'description': 'ITEM NOT ...             FINISHED
# 985  [{'barcode': '4011', 'description': 'ITEM NOT ...             FINISHED
# 990  [{'barcode': '4011', 'description': 'ITEM NOT ...             FINISHED
#
#      totalSpent                    userId                receipt_id  \
# 13         1.00  5f9c74f7c88c1415cbddb839  5f9c74f70a7214ad07000037
# 15         0.00  5ff1e1e9b6a9d73a3a9f10f6  5ff1e1e90a7214ada1000569
# 16        11.00  5ff1e1dfcfcf6c399c274ab3  5ff1e1df0a7214ada1000564
# 20        14.00  5f9c74e3f1937815bd2c1d73  5f9c74f90a7214ad07000038
# 21         1.00  5ff1e196cfcf6c399c274a38  5ff1e1960a720f0523000567
# ..          ...                       ...                       ...
# 955        2.23  60253861efa6017a44dc6b50  602538740a7214d8e9000246
# 956       20.00  60253891b54593795bf69242  602538920a720f05a8000216
# 966       23.00  60253891b54593795bf69242  602538960a720f05a800021b
# 985       29.00  60268c7bb545931ac63683af  60268c7e0a7214d8e9000309
# 990       25.00  60268c78efa6011bb151077d  60268c790a7214d8e9000306
#
#            created_date_time        scanned_date_time  \
# 13   2020-10-30 15:17:59.000  2020-10-30 15:17:59.000
# 15   2021-01-03 09:25:29.000  2021-01-03 09:25:29.000
# 16   2021-01-03 09:25:19.000  2021-01-03 09:25:19.000
# 20   2020-10-30 15:18:01.000  2020-10-30 15:18:01.000
# 21   2021-01-03 09:24:06.000  2021-01-03 09:24:06.000
# ..                       ...                      ...
# 955  2021-02-11 08:00:20.000  2021-02-11 08:00:20.000
# 956  2021-02-11 08:00:50.000  2021-02-11 08:00:50.000
# 966  2021-02-11 08:00:53.000  2021-02-11 08:00:53.000
# 985  2021-02-12 08:11:10.000  2021-02-12 08:11:10.000
# 990  2021-02-12 08:11:05.000  2021-02-12 08:11:05.000
#
#           finished_date_time         modify_date_time pointsAwarded_date_time  \
# 13                       NaN  2021-01-03 09:24:54.000     2020-10-30 15:18:00
# 15                       NaN  2021-01-03 09:25:29.000                     NaN
# 16   2021-01-03 09:25:20.000  2021-01-03 09:25:25.000     2021-01-03 09:25:19
# 20   2021-01-03 09:39:55.000  2021-01-03 09:39:55.000     2021-01-03 09:39:55
# 21   2021-01-03 09:24:10.000  2021-01-03 09:24:10.000     2021-01-03 09:24:10
# ..                       ...                      ...                     ...
# 955  2021-02-11 08:00:22.000  2021-02-11 08:00:23.000     2021-02-11 08:00:22
# 956  2021-02-11 08:00:50.000  2021-02-11 08:00:55.000     2021-02-11 08:00:50
# 966  2021-02-11 08:00:54.000  2021-02-11 08:00:59.000     2021-02-11 08:00:54
# 985  2021-02-12 08:11:11.000  2021-02-12 08:11:16.000     2021-02-12 08:11:11
# 990  2021-02-12 08:11:05.000  2021-02-12 08:11:11.000     2021-02-12 08:11:05
#
#      purchased_date_time
# 13   2020-10-29 15:17:59
# 15                   NaN
# 16   2021-01-02 09:25:19
# 20   2020-10-29 15:18:01
# 21   2021-01-02 09:24:06
# ..                   ...
# 955  2021-02-11 08:00:20
# 956  2021-02-10 18:00:00
# 966  2021-02-10 18:00:00
# 985  2021-02-11 18:00:00
# 990  2021-02-11 18:00:00
#
# [148 rows x 15 columns]

# %% [markdown]
# ### data Quality issue Spotted!! there are users ids that are present in the receipts but not present in users_df.

# %% [markdown]
# #### Data Quality issues in rewards_receipts_df

# %%
rewards_receipts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6941 entries, 0 to 6940
# Data columns (total 35 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   barcode                             3090 non-null   object
#  1   description                         6560 non-null   object
#  2   finalPrice                          6767 non-null   float64
#  3   itemPrice                           6767 non-null   float64
#  4   needsFetchReview                    813 non-null    object
#  5   partnerItemId                       6941 non-null   int64
#  6   preventTargetGapPoints              358 non-null    object
#  7   quantityPurchased                   6767 non-null   float64
#  8   userFlaggedBarcode                  337 non-null    float64
#  9   userFlaggedNewItem                  323 non-null    object
#  10  userFlaggedPrice                    299 non-null    float64
#  11  userFlaggedQuantity                 299 non-null    float64
#  12  needsFetchReviewReason              219 non-null    object
#  13  pointsNotAwardedReason              340 non-null    object
#  14  pointsPayerId                       1267 non-null   object
#  15  rewardsGroup                        1731 non-null   object
#  16  rewardsProductPartnerId             2269 non-null   object
#  17  userFlaggedDescription              154 non-null    object
#  18  originalMetaBriteBarcode            24 non-null     float64
#  19  originalMetaBriteDescription        10 non-null     object
#  20  brandCode                           2600 non-null   object
#  21  competitorRewardsGroup              275 non-null    object
#  22  discountedItemPrice                 5769 non-null   float64
#  23  originalReceiptItemText             5760 non-null   object
#  24  itemNumber                          153 non-null    float64
#  25  originalMetaBriteQuantityPurchased  15 non-null     float64
#  26  pointsEarned                        927 non-null    float64
#  27  targetPrice                         378 non-null    float64
#  28  competitiveProduct                  645 non-null    object
#  29  originalFinalPrice                  9 non-null      float64
#  30  originalMetaBriteItemPrice          9 non-null      float64
#  31  deleted                             9 non-null      object
#  32  priceAfterCoupon                    956 non-null    float64
#  33  metabriteCampaignId                 863 non-null    object
#  34  receipt_id                          6941 non-null   object
# dtypes: float64(15), int64(1), object(19)
# memory usage: 1.9+ MB

# %%
## Unique test:

context = ge.get_context()
data_source = context.data_sources.add_pandas("pandas")
data_asset = data_source.add_dataframe_asset(name="pd dataframe asset")

batch_definition = data_asset.add_batch_definition_whole_dataframe("batch definition")

batch = batch_definition.get_batch(batch_parameters={"dataframe": rewards_receipts_df})

#expect user_id to exist:
compound_unique_rr_expectation = ge.expectations.ExpectCompoundColumnsToBeUnique(column_list = ['receipt_id','partnerItemId'])
validation_result = batch.validate(compound_unique_rr_expectation)
print(validation_result['result'])
# Out:
# Calculating Metrics:   0%|          | 0/9 [00:00<?, ?it/s]
# {'element_count': 6941, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'partial_unexpected_list': [], 'missing_count': 0, 'missing_percent': 0.0, 'unexpected_percent_total': 0.0, 'unexpected_percent_nonmissing': 0.0, 'partial_unexpected_counts': [], 'partial_unexpected_index_list': []}

# %%
# passed unique test!

# %% [markdown]
# Digging into missing values:

# %% [markdown]
# For everyitem that is scanned is expected to have a barcode.

# %%
rewards_receipts_df[rewards_receipts_df['barcode'].isna()].head()
# Out:
#    barcode   description  finalPrice  itemPrice needsFetchReview  \
# 3      NaN           NaN         NaN        NaN            False
# 8      NaN  MSSN TORTLLA        2.23       2.23              NaN
# 25     NaN           NaN         NaN        NaN             True
# 26     NaN           NaN         NaN        NaN             True
# 27     NaN           NaN         NaN        NaN             True
#
#     partnerItemId preventTargetGapPoints  quantityPurchased  \
# 3               1                   True                NaN
# 8            1009                    NaN                1.0
# 25              2                   True                NaN
# 26              3                   True                NaN
# 27              4                   True                NaN
#
#     userFlaggedBarcode userFlaggedNewItem  userFlaggedPrice  \
# 3         4.011000e+03               True              26.0
# 8                  NaN                NaN               NaN
# 25        3.410057e+10               True              29.0
# 26        3.410057e+10               True              29.0
# 27        3.410057e+10               True              29.0
#
#     userFlaggedQuantity needsFetchReviewReason pointsNotAwardedReason  \
# 3                   3.0                    NaN                    NaN
# 8                   NaN                    NaN                    NaN
# 25                  1.0           USER_FLAGGED                    NaN
# 26                  1.0           USER_FLAGGED                    NaN
# 27                  1.0           USER_FLAGGED                    NaN
#
#    pointsPayerId rewardsGroup rewardsProductPartnerId  \
# 3            NaN          NaN                     NaN
# 8            NaN          NaN                     NaN
# 25           NaN          NaN                     NaN
# 26           NaN          NaN                     NaN
# 27           NaN          NaN                     NaN
#
#           userFlaggedDescription  originalMetaBriteBarcode  \
# 3                            NaN                       NaN
# 8                            NaN                       NaN
# 25  MILLER LITE 24 PACK 12OZ CAN                       NaN
# 26  MILLER LITE 24 PACK 12OZ CAN                       NaN
# 27  MILLER LITE 24 PACK 12OZ CAN                       NaN
#
#    originalMetaBriteDescription brandCode competitorRewardsGroup  \
# 3                           NaN       NaN                    NaN
# 8                           NaN   MISSION  TACO BELL TACO SHELLS
# 25                          NaN       NaN                    NaN
# 26                          NaN       NaN                    NaN
# 27                          NaN       NaN                    NaN
#
#     discountedItemPrice originalReceiptItemText  itemNumber  \
# 3                   NaN                     NaN         NaN
# 8                  2.23            MSSN TORTLLA         NaN
# 25                  NaN                     NaN         NaN
# 26                  NaN                     NaN         NaN
# 27                  NaN                     NaN         NaN
#
#     originalMetaBriteQuantityPurchased  pointsEarned  targetPrice  \
# 3                                  NaN           NaN          NaN
# 8                                  NaN           NaN          NaN
# 25                                 NaN           NaN          NaN
# 26                                 NaN           NaN          NaN
# 27                                 NaN           NaN          NaN
#
#    competitiveProduct  originalFinalPrice  originalMetaBriteItemPrice deleted  \
# 3                 NaN                 NaN                         NaN     NaN
# 8                 NaN                 NaN                         NaN     NaN
# 25                NaN                 NaN                         NaN     NaN
# 26                NaN                 NaN                         NaN     NaN
# 27                NaN                 NaN                         NaN     NaN
#
#     priceAfterCoupon metabriteCampaignId                receipt_id
# 3                NaN                 NaN  5ff1e1f10a720f052300057a
# 8                NaN                 NaN  5ff1e1cd0a720f052300056f
# 25               NaN                 NaN  5f9c74f70a7214ad07000037
# 26               NaN                 NaN  5f9c74f70a7214ad07000037
# 27               NaN                 NaN  5f9c74f70a7214ad07000037

# %% [markdown]
# #### data Quality issue spotted!

# %%
rewards_receipts_df[rewards_receipts_df['barcode'].isna()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3851 entries, 3 to 6847
# Data columns (total 35 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   barcode                             0 non-null      object
#  1   description                         3701 non-null   object
#  2   finalPrice                          3701 non-null   float64
#  3   itemPrice                           3701 non-null   float64
#  4   needsFetchReview                    453 non-null    object
#  5   partnerItemId                       3851 non-null   int64
#  6   preventTargetGapPoints              150 non-null    object
#  7   quantityPurchased                   3701 non-null   float64
#  8   userFlaggedBarcode                  150 non-null    float64
#  9   userFlaggedNewItem                  150 non-null    object
#  10  userFlaggedPrice                    150 non-null    float64
#  11  userFlaggedQuantity                 150 non-null    float64
#  12  needsFetchReviewReason              146 non-null    object
#  13  pointsNotAwardedReason              0 non-null      object
#  14  pointsPayerId                       0 non-null      object
#  15  rewardsGroup                        25 non-null     object
#  16  rewardsProductPartnerId             45 non-null     object
#  17  userFlaggedDescription              136 non-null    object
#  18  originalMetaBriteBarcode            0 non-null      float64
#  19  originalMetaBriteDescription        0 non-null      object
#  20  brandCode                           854 non-null    object
#  21  competitorRewardsGroup              101 non-null    object
#  22  discountedItemPrice                 3686 non-null   float64
#  23  originalReceiptItemText             3692 non-null   object
#  24  itemNumber                          0 non-null      float64
#  25  originalMetaBriteQuantityPurchased  0 non-null      float64
#  26  pointsEarned                        0 non-null      float64
#  27  targetPrice                         0 non-null      float64
#  28  competitiveProduct                  45 non-null     object
#  29  originalFinalPrice                  0 non-null      float64
#  30  originalMetaBriteItemPrice          0 non-null      float64
#  31  deleted                             9 non-null      object
#  32  priceAfterCoupon                    566 non-null    float64
#  33  metabriteCampaignId                 25 non-null     object
#  34  receipt_id                          3851 non-null   object
# dtypes: float64(15), int64(1), object(19)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Below table suggests that orders that have descriptions but no barcode could suggest potential data quality issue in terms of scanning.

# %%
missing_brandcode_desc_present_df = rewards_receipts_df[(rewards_receipts_df['brandCode'].isna()) & (~rewards_receipts_df['description'].isna())]

# %%
missing_brandcode_desc_present_df['first_word_desc'] = missing_brandcode_desc_present_df['description'].apply(lambda x: x.split()[0])
# Out:
# C:\Users\pragn\AppData\Local\Temp\ipykernel_33756\2402561359.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   missing_brandcode_desc_present_df['first_word_desc'] = missing_brandcode_desc_present_df['description'].apply(lambda x: x.split()[0])

# %%
missing_brandcode_desc_present_df.groupby('first_word_desc').agg({'first_word_desc':'size'}).rename(columns={'first_word_desc':'count'}).sort_values(by = ['count'],ascending= False).head(25)
# Out:
#                  count
# first_word_desc
# ITEM               173
# PC                 138
# KLARBRUNN          128
# HUGGIES             93
# MILLER              90
# HYV                 84
# COMP                74
# OSCAR               73
# LEGO                56
# EMIL'               55
# PLAY                55
# flipbelt            50
# SIG                 47
# thindust            44
# mueller             44
# Green               43
# KRAFT               38
# EMILS               32
# HEINZ               32
# CHEESE              31
# BEN                 30
# PLANTERS            26
# TC                  25
# BORDEN              25
# ALASKA              23

# %%
missing_brandcode_desc_present_df[missing_brandcode_desc_present_df['first_word_desc'] == 'BORDEN']['description'].head()
# Out:
# 1000    BORDEN 2% MILK, 1/2 GAL
# 1003    BORDEN 2% MILK, 1/2 GAL
# 1012    BORDEN 2% MILK, 1/2 GAL
# 1015    BORDEN 2% MILK, 1/2 GAL
# 1132    BORDEN 2% MILK, 1/2 GAL
# Name: description, dtype: object

# %%
missing_brandcode_desc_present_df[missing_brandcode_desc_present_df['first_word_desc'] == 'KLARBRUNN'][['description','brandCode']].head()
# Out:
#                  description brandCode
# 305  KLARBRUNN 12PK 12 FL OZ       NaN
# 307  KLARBRUNN 12PK 12 FL OZ       NaN
# 624  KLARBRUNN 12PK 12 FL OZ       NaN
# 648  KLARBRUNN 12PK 12 SL OZ       NaN
# 884  KLARBRUNN 12PK 12 FL OZ       NaN

# %% [markdown]
# ##### The above tables are examples where barcodes are present but one would make sense out of the brands based on description. By 'estimating' the brand from description can help better the analysis made over brands especially the number of scanned items. A better way of imputing brandCodes should be devised in order to improve the understanding of the scanning and receipt flow.
#
# Example: If not for better imputing methods, the 138 scanned receipts of 'Klarbrunn' brand would not counted for let's say which brand is mostly contributing to water etc

# %% [markdown]
# ### Checking if the brandCodes present in the rewards_receipts_table are actually present in the brands table.

# %%
##checking if unique brandcodes exist in receipt but not in brands

brandcodes_rewards_receipt = list(rewards_receipts_df['brandCode'].unique())
brandcodes_brands = list(brands_df['brandCode'].unique())
len(brandcodes_rewards_receipt)
missing_bar_codes = [x for x in brandcodes_rewards_receipt if x not in brandcodes_brands]
sorted(missing_bar_codes)
# Out:
# ['7UP',
#  'ADVIL',
#  'AMERICAN BEAUTY',
#  'ARROWHEAD',
#  'AZTECA',
#  'BANZA',
#  'BEAR CREEK COUNTRY KITCHENS',
#  'BEN AND JERRYS',
#  'BETTY CROCKER',
#  'BIC',
#  'BIGELOW',
#  'BLUE DIAMOND',
#  "BOAR'S HEAD",
#  'BORDEN',
#  'BOTA BOX',
#  'BRAND',
#  "BRASWELL'S",
#  'BUNNY',
#  "BUSH'S BEST",
#  'C&H',
#  'CADBURY',
#  'CAL-ORGANIC FARMS',
#  'CALIFIA FARMS',
#  "CAMPBELL'S",
#  'CARAMELLO',
#  'CHEERIOS',
#  'CHEESE',
#  'CHEEZ-IT',
#  'CHEX',
#  'CHICKEN OF THE SEA',
#  'CHIQUITA',
#  'CINNAMON TOAST CRUNCH',
#  'COKE',
#  'COLEMAN NATURAL',
#  "CONNIE'S PIZZA",
#  'CREST 3D WHITE',
#  'CRISPIX',
#  'DANNON',
#  'DARE',
#  'DELI',
#  'DIET COKE',
#  'DIGIORNO',
#  'DOLE',
#  'DR PEPPER',
#  'EDWARDS',
#  "EGGLAND'S BEST",
#  'EGGO',
#  'EL MONTEREY',
#  'ENERGIZER MAX',
#  'ESSENTIAL EVERYDAY',
#  'FAGE',
#  "FAMOUS DAVE'S",
#  "FLORIDA'S NATURAL",
#  'FOLGERS',
#  'FORTUNE YAKISOBA',
#  'FRANZ',
#  "FRENCH'S",
#  'FRESH EXPRESS',
#  'FRESH STEP',
#  'FRONTERA',
#  'GALLO FAMILY VINEYARDS',
#  'GENERAL MILLS',
#  'GERBER',
#  'GERM-X',
#  'GREEN GIANT',
#  'GRIMMWAY FARMS',
#  'HANOVER',
#  'HARVEST SNAPS',
#  'HATCH FARMS',
#  'HAWAIIAN',
#  "HEMPLER'S",
#  'HERITAGE FARM',
#  "HERSHEY'S KISSES",
#  'HEWLETT PACKARD',
#  'HIDDEN VALLEY',
#  'HILLSHIRE FARM',
#  'HONEY BUNCHES OF OATS',
#  'HORMEL',
#  'HY-VEE',
#  'HY-VEE SELECT',
#  "JACK DANIEL'S READY TO EAT",
#  "JACK LINK'S",
#  'JELLY BELLY',
#  'JENNIE-O',
#  'JIMMY DEAN',
#  'JOHN SOULES FOODS',
#  'JOHNSONVILLE',
#  'JUST BARE',
#  'KARO',
#  'KASHI',
#  "KELLOGG'S",
#  'KEMPS',
#  'KERR',
#  'KERRYGOLD',
#  'KIKKOMAN',
#  'KING ARTHUR FLOUR',
#  'KIT KAT',
#  'KITCHEN BASICS',
#  'KLARBRUNN',
#  'KRAFT EASY CHEESE',
#  'KRAZY GLUE',
#  'KROGER',
#  'KRUSTEAZ',
#  'LA BANDERITA',
#  "LAURA'S LEAN BEEF",
#  'LIGHT & FIT',
#  'LIGHT & FIT GREEK',
#  'LINDSAY',
#  'LINDT',
#  'LIPTON',
#  'LITEHOUSE',
#  'LUNDBERG FAMILY FARMS',
#  "MARIE CALLENDER'S",
#  "MARIE'S",
#  "MARTINELLI'S",
#  'MCCORMICK',
#  'MCCORMICK GRILL MATES',
#  "MERKT'S",
#  'MISSION',
#  'MORTON',
#  "MRS. CUBBISON'S",
#  "MRS. RENFRO'S",
#  'NABISCO',
#  "NATURE'S PATH ORGANIC",
#  'NESTLE',
#  'NUTELLA',
#  'NUTRI-GRAIN',
#  'OLD EL PASO',
#  'ORAL-B GLIDE',
#  'ORBIT',
#  'OREO',
#  'ORGANIC ROOT STIMULATOR',
#  'ORGANICVILLE',
#  'OVALTINE',
#  'PEARLS',
#  'PILLSBURY',
#  'PLAYTEX',
#  'POMPEIAN',
#  'POWER CRUNCH',
#  'PRINGLES',
#  'PRIVATE SELECTION',
#  'PROGRESSO',
#  'PURINA ONE',
#  'R.W. KNUDSEN',
#  'RAGU',
#  "REESE'S",
#  'RENUZIT',
#  'RITZ',
#  'RITZ TOASTED CHIPS',
#  'ROSARITA',
#  'SABRA',
#  "SCHWEBEL'S",
#  'SHOPRITE',
#  'SIGNATURE',
#  'SIGNATURE KITCHEN',
#  'SIMPLE TRUTH',
#  'SIMPLE TRUTH ORGANIC',
#  'SIMPLY POTATOES',
#  'SKITTLES',
#  'SMITHFIELD',
#  'SO DELICIOUS',
#  'SPARKLING ICE',
#  'SPECIAL K',
#  'STARKIST',
#  "STOUFFER'S",
#  "STOUFFER'S CLASSICS",
#  'TAYLOR FARMS',
#  'TEMPTATIONS',
#  'THAI KITCHEN',
#  "THAT'S SMART!",
#  'THOMAS',
#  'THOMAS ENGLISH MUFFINS',
#  "THOMAS'",
#  'TIC TAC',
#  'TILLAMOOK',
#  'TOLL HOUSE',
#  'TOP FLIGHT',
#  'TROLLI',
#  'TYSON',
#  "VAN DE KAMP'S",
#  'VITAL FARMS ALFRESCO EGGS',
#  "WELCH'S",
#  'WINGSTOP',
#  'WISHBONE',
#  'WONDERFUL',
#  'ZESTA']

# %% [markdown]
# ### Are they actually missing???
# Ans: No
#
# Example:
# 1) '7UP' present in receipt rewards table; and '7 up' is present in brands_df => which are actually the same brands. There is a need to maintain a consistent structure in the brandCodes.
# 2) "BEN AND JERRYS" and "BEN & JERRY'S" in rewards_receipts_df and brands_df respectively.
#
# There are multiple examples like these which proves the lack of consistency in determining BrandCodes

# %% [markdown]
# ### Loading the dfs into MYSQL

# %%
users_df_no_duplicates.head()
# Out:
#    active      role signUpSource state                   user_id  \
# 0    True  consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# 3    True  consumer        Email    WI  5ff1e1eacfcf6c399c274ae6
# 6    True  consumer        Email    WI  5ff1e1e8cfcf6c399c274ad9
# 7    True  consumer        Email    WI  5ff1e1b7cfcf6c399c274a5a
# 9    True  consumer        Email    WI  5ff1e1f1cfcf6c399c274b0b
#
#          created_date_time      lastLogin_date_time
# 0  2021-01-03 09:24:04.800  2021-01-03 09:25:37.858
# 3  2021-01-03 09:25:30.554  2021-01-03 09:25:30.597
# 6  2021-01-03 09:25:28.354  2021-01-03 09:25:28.392
# 7  2021-01-03 09:24:39.626  2021-01-03 09:24:39.665
# 9  2021-01-03 09:25:37.564  2021-01-03 09:25:37.599

# %%
brands_df.head()
# Out:
#         barcode        category      categoryCode                       name  \
# 0  511111019862          Baking            BAKING  test brand @1612366101024
# 1  511111519928       Beverages         BEVERAGES                  Starbucks
# 2  511111819905          Baking            BAKING  test brand @1612366146176
# 3  511111519874          Baking            BAKING  test brand @1612366146051
# 4  511111319917  Candy & Sweets  CANDY_AND_SWEETS  test brand @1612366146827
#
#   topBrand                  brand_id                    cpg_id cpg_ref  \
# 0    False  601ac115be37ce2ead437551  601ac114be37ce2ead437550    Cogs
# 1    False  601c5460be37ce2ead43755f  5332f5fbe4b03c9a25efd0ba    Cogs
# 2    False  601ac142be37ce2ead43755d  601ac142be37ce2ead437559    Cogs
# 3    False  601ac142be37ce2ead43755a  601ac142be37ce2ead437559    Cogs
# 4    False  601ac142be37ce2ead43755e  5332fa12e4b03c9a25efd1e7    Cogs
#
#                        brandCode
# 0                            NaN
# 1                      STARBUCKS
# 2  TEST BRANDCODE @1612366146176
# 3  TEST BRANDCODE @1612366146051
# 4  TEST BRANDCODE @1612366146827

# %%
new_receipts_df = receipts_df.drop(columns = 'rewardsReceiptItemList')
new_receipts_df.head()
# Out:
#    bonusPointsEarned                            bonusPointsEarnedReason  \
# 0              500.0  Receipt number 2 completed, bonus point schedu...
# 1              150.0  Receipt number 5 completed, bonus point schedu...
# 2                5.0                         All-receipts receipt bonus
# 3                5.0                         All-receipts receipt bonus
# 4                5.0                         All-receipts receipt bonus
#
#    pointsEarned  purchasedItemCount rewardsReceiptStatus  totalSpent  \
# 0         500.0                 5.0             FINISHED        26.0
# 1         150.0                 2.0             FINISHED        11.0
# 2           5.0                 1.0             REJECTED        10.0
# 3           5.0                 4.0             FINISHED        28.0
# 4           5.0                 2.0             FINISHED         1.0
#
#                      userId                receipt_id  \
# 0  5ff1e1eacfcf6c399c274ae6  5ff1e1eb0a720f0523000575
# 1  5ff1e194b6a9d73a3a9f1052  5ff1e1bb0a720f052300056b
# 2  5ff1e1f1cfcf6c399c274b0b  5ff1e1f10a720f052300057a
# 3  5ff1e1eacfcf6c399c274ae6  5ff1e1ee0a7214ada100056f
# 4  5ff1e194b6a9d73a3a9f1052  5ff1e1d20a7214ada1000561
#
#          created_date_time        scanned_date_time       finished_date_time  \
# 0  2021-01-03 09:25:31.000  2021-01-03 09:25:31.000  2021-01-03 09:25:31.000
# 1  2021-01-03 09:24:43.000  2021-01-03 09:24:43.000  2021-01-03 09:24:43.000
# 2  2021-01-03 09:25:37.000  2021-01-03 09:25:37.000                      NaN
# 3  2021-01-03 09:25:34.000  2021-01-03 09:25:34.000  2021-01-03 09:25:34.000
# 4  2021-01-03 09:25:06.000  2021-01-03 09:25:06.000  2021-01-03 09:25:11.000
#
#           modify_date_time pointsAwarded_date_time  purchased_date_time
# 0  2021-01-03 09:25:36.000     2021-01-03 09:25:31  2021-01-02 18:00:00
# 1  2021-01-03 09:24:48.000     2021-01-03 09:24:43  2021-01-02 09:24:43
# 2  2021-01-03 09:25:42.000                     NaN  2021-01-02 18:00:00
# 3  2021-01-03 09:25:39.000     2021-01-03 09:25:34  2021-01-02 18:00:00
# 4  2021-01-03 09:25:11.000     2021-01-03 09:25:06  2021-01-02 09:25:06

# %%
rewards_receipts_df.head()
# Out:
#         barcode                                        description  \
# 0          4011                                     ITEM NOT FOUND
# 1          4011                                     ITEM NOT FOUND
# 2  028400642255  DORITOS TORTILLA CHIP SPICY SWEET CHILI REDUCE...
# 3           NaN                                                NaN
# 4          4011                                     ITEM NOT FOUND
#
#    finalPrice  itemPrice needsFetchReview  partnerItemId  \
# 0        26.0       26.0            False              1
# 1         1.0        1.0              NaN              1
# 2        10.0       10.0             True              2
# 3         NaN        NaN            False              1
# 4        28.0       28.0            False              1
#
#   preventTargetGapPoints  quantityPurchased  userFlaggedBarcode  \
# 0                   True                5.0        4.011000e+03
# 1                    NaN                1.0                 NaN
# 2                   True                1.0        2.840064e+10
# 3                   True                NaN        4.011000e+03
# 4                   True                4.0        4.011000e+03
#
#   userFlaggedNewItem  userFlaggedPrice  userFlaggedQuantity  \
# 0               True              26.0                  5.0
# 1                NaN               NaN                  NaN
# 2               True              10.0                  1.0
# 3               True              26.0                  3.0
# 4               True              28.0                  4.0
#
#   needsFetchReviewReason               pointsNotAwardedReason  \
# 0                    NaN                                  NaN
# 1                    NaN                                  NaN
# 2           USER_FLAGGED  Action not allowed for user and CPG
# 3                    NaN                                  NaN
# 4                    NaN                                  NaN
#
#               pointsPayerId                            rewardsGroup  \
# 0                       NaN                                     NaN
# 1                       NaN                                     NaN
# 2  5332f5fbe4b03c9a25efd0ba  DORITOS SPICY SWEET CHILI SINGLE SERVE
# 3                       NaN                                     NaN
# 4                       NaN                                     NaN
#
#     rewardsProductPartnerId  \
# 0                       NaN
# 1                       NaN
# 2  5332f5fbe4b03c9a25efd0ba
# 3                       NaN
# 4                       NaN
#
#                               userFlaggedDescription  \
# 0                                                NaN
# 1                                                NaN
# 2  DORITOS TORTILLA CHIP SPICY SWEET CHILI REDUCE...
# 3                                                NaN
# 4                                                NaN
#
#    originalMetaBriteBarcode originalMetaBriteDescription brandCode  \
# 0                       NaN                          NaN       NaN
# 1                       NaN                          NaN       NaN
# 2                       NaN                          NaN       NaN
# 3                       NaN                          NaN       NaN
# 4                       NaN                          NaN       NaN
#
#   competitorRewardsGroup  discountedItemPrice originalReceiptItemText  \
# 0                    NaN                  NaN                     NaN
# 1                    NaN                  NaN                     NaN
# 2                    NaN                  NaN                     NaN
# 3                    NaN                  NaN                     NaN
# 4                    NaN                  NaN                     NaN
#
#    itemNumber  originalMetaBriteQuantityPurchased  pointsEarned  targetPrice  \
# 0         NaN                                 NaN           NaN          NaN
# 1         NaN                                 NaN           NaN          NaN
# 2         NaN                                 NaN           NaN          NaN
# 3         NaN                                 NaN           NaN          NaN
# 4         NaN                                 NaN           NaN          NaN
#
#   competitiveProduct  originalFinalPrice  originalMetaBriteItemPrice deleted  \
# 0                NaN                 NaN                         NaN     NaN
# 1                NaN                 NaN                         NaN     NaN
# 2                NaN                 NaN                         NaN     NaN
# 3                NaN                 NaN                         NaN     NaN
# 4                NaN                 NaN                         NaN     NaN
#
#    priceAfterCoupon metabriteCampaignId                receipt_id
# 0               NaN                 NaN  5ff1e1eb0a720f0523000575
# 1               NaN                 NaN  5ff1e1bb0a720f052300056b
# 2               NaN                 NaN  5ff1e1bb0a720f052300056b
# 3               NaN                 NaN  5ff1e1f10a720f052300057a
# 4               NaN                 NaN  5ff1e1ee0a7214ada100056f

# %%
# Function to read YAML file
def read_yaml(file_path):
    with open(file_path, 'r') as file:
        try:
            # Load the YAML content into a Python dictionary
            data = yaml.safe_load(file)
            return data
        except yaml.YAMLError as exc:
            print(f"Error reading YAML file: {exc}")
            return None

# %%
file_path = os.path.join(root_dir,'MYSQL_user_config.yaml')
config = read_yaml(file_path)

user = config.get('MYSQL_credentials')['user']
password = config.get('MYSQL_credentials')['password']
host = config.get('MYSQL_credentials')['host']
port = config.get('MYSQL_credentials')['port']

# %% [markdown]
# ##### Make sure that MYSQL 'services' is running locally (Can always check witn Win + R and searching for services.msc) and starting MYSQL

# %%
def create_database(db_url, db_name):
    try:
        # Connect to MySQL using SQLAlchemy's engine
        engine = create_engine(db_url)
        with engine.connect() as connection:
            # Execute the command to create a database
            connection.execute(text(f"CREATE DATABASE IF NOT EXISTS {db_name}"))
            print(f"Database '{db_name}' created successfully!")
    except Exception as e:
        print(f"Error while creating database: {e}")

db_url = f'mysql+pymysql://{user}:{password}@{host}:{port}'
db_name = "FETCH_DB"


create_database(db_url, db_name)
# Out:
# Database 'FETCH_DB' created successfully!

# %%
def run_query(query):
    try:
        with engine.connect() as connection:
            result = connection.execute(text(query))
            return result.fetchall()
    except Exception as e:
        print(f"Error in the query -> {e}")

# %%
##Engine creation for data loading
engine = create_engine(f'{db_url}'+'/'+f'{db_name}')

# %%
users_df_no_duplicates.head()
# Out:
#    active      role signUpSource state                   user_id  \
# 0    True  consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# 3    True  consumer        Email    WI  5ff1e1eacfcf6c399c274ae6
# 6    True  consumer        Email    WI  5ff1e1e8cfcf6c399c274ad9
# 7    True  consumer        Email    WI  5ff1e1b7cfcf6c399c274a5a
# 9    True  consumer        Email    WI  5ff1e1f1cfcf6c399c274b0b
#
#          created_date_time      lastLogin_date_time
# 0  2021-01-03 09:24:04.800  2021-01-03 09:25:37.858
# 3  2021-01-03 09:25:30.554  2021-01-03 09:25:30.597
# 6  2021-01-03 09:25:28.354  2021-01-03 09:25:28.392
# 7  2021-01-03 09:24:39.626  2021-01-03 09:24:39.665
# 9  2021-01-03 09:25:37.564  2021-01-03 09:25:37.599

# %%
users_df_no_duplicates[~users_df_no_duplicates['role'].isna()]['role'].apply(lambda x:len(x)).max()
# Out:
# 11

# %%
users_df_no_duplicates['active'] = users_df_no_duplicates['active'].apply(lambda x:str(x).upper())
# Out:
# C:\Users\pragn\AppData\Local\Temp\ipykernel_33756\4203549089.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users_df_no_duplicates['active'] = users_df_no_duplicates['active'].apply(lambda x:str(x).upper())

# %%
create_user_df_query = """
CREATE TABLE users (
    user_id VARCHAR(24) PRIMARY KEY,
    created_date_time DATETIME(3),
    lastLogin_date_time DATETIME(3),
    state VARCHAR(2),
    signUpSource VARCHAR(15),
    role VARCHAR(15),
    active BOOLEAN
)
"""
run_query('DROP TABLE IF EXISTS users')
run_query(create_user_df_query)
# Out:
# Error in the query -> This result object does not return rows. It has been closed automatically.

# %%
brands_df.head()
# Out:
#         barcode        category      categoryCode                       name  \
# 0  511111019862          Baking            BAKING  test brand @1612366101024
# 1  511111519928       Beverages         BEVERAGES                  Starbucks
# 2  511111819905          Baking            BAKING  test brand @1612366146176
# 3  511111519874          Baking            BAKING  test brand @1612366146051
# 4  511111319917  Candy & Sweets  CANDY_AND_SWEETS  test brand @1612366146827
#
#   topBrand                  brand_id                    cpg_id cpg_ref  \
# 0    False  601ac115be37ce2ead437551  601ac114be37ce2ead437550    Cogs
# 1    False  601c5460be37ce2ead43755f  5332f5fbe4b03c9a25efd0ba    Cogs
# 2    False  601ac142be37ce2ead43755d  601ac142be37ce2ead437559    Cogs
# 3    False  601ac142be37ce2ead43755a  601ac142be37ce2ead437559    Cogs
# 4    False  601ac142be37ce2ead43755e  5332fa12e4b03c9a25efd1e7    Cogs
#
#                        brandCode
# 0                            NaN
# 1                      STARBUCKS
# 2  TEST BRANDCODE @1612366146176
# 3  TEST BRANDCODE @1612366146051
# 4  TEST BRANDCODE @1612366146827

# %%
brands_df[~brands_df['brandCode'].isna()]['brandCode'].apply(lambda x:len(x)).max()
# Out:
# 46

# %%
brands_df['topBrand'] = brands_df['topBrand'].apply(lambda x:str(x).upper())

# %%
create_brands_df_query = """
CREATE TABLE brands (
    brand_id VARCHAR(24) PRIMARY KEY,
    name VARCHAR(25),
    category VARCHAR(25),
    categoryCode VARCHAR(25),
    barcode VARCHAR(20),
    cpg_id VARCHAR(6),
    cpg_ref VARCHAR(6),
    brandCode VARCHAR(50),
    topBrand BOOLEAN
);
"""
run_query('DROP TABLE IF EXISTS brands')
run_query(create_brands_df_query)
# Out:
# Error in the query -> This result object does not return rows. It has been closed automatically.
# Error in the query -> This result object does not return rows. It has been closed automatically.

# %%
new_receipts_df.head()
# Out:
#    bonusPointsEarned                            bonusPointsEarnedReason  \
# 0              500.0  Receipt number 2 completed, bonus point schedu...
# 1              150.0  Receipt number 5 completed, bonus point schedu...
# 2                5.0                         All-receipts receipt bonus
# 3                5.0                         All-receipts receipt bonus
# 4                5.0                         All-receipts receipt bonus
#
#    pointsEarned  purchasedItemCount rewardsReceiptStatus  totalSpent  \
# 0         500.0                 5.0             FINISHED        26.0
# 1         150.0                 2.0             FINISHED        11.0
# 2           5.0                 1.0             REJECTED        10.0
# 3           5.0                 4.0             FINISHED        28.0
# 4           5.0                 2.0             FINISHED         1.0
#
#                      userId                receipt_id  \
# 0  5ff1e1eacfcf6c399c274ae6  5ff1e1eb0a720f0523000575
# 1  5ff1e194b6a9d73a3a9f1052  5ff1e1bb0a720f052300056b
# 2  5ff1e1f1cfcf6c399c274b0b  5ff1e1f10a720f052300057a
# 3  5ff1e1eacfcf6c399c274ae6  5ff1e1ee0a7214ada100056f
# 4  5ff1e194b6a9d73a3a9f1052  5ff1e1d20a7214ada1000561
#
#          created_date_time        scanned_date_time       finished_date_time  \
# 0  2021-01-03 09:25:31.000  2021-01-03 09:25:31.000  2021-01-03 09:25:31.000
# 1  2021-01-03 09:24:43.000  2021-01-03 09:24:43.000  2021-01-03 09:24:43.000
# 2  2021-01-03 09:25:37.000  2021-01-03 09:25:37.000                      NaN
# 3  2021-01-03 09:25:34.000  2021-01-03 09:25:34.000  2021-01-03 09:25:34.000
# 4  2021-01-03 09:25:06.000  2021-01-03 09:25:06.000  2021-01-03 09:25:11.000
#
#           modify_date_time pointsAwarded_date_time  purchased_date_time
# 0  2021-01-03 09:25:36.000     2021-01-03 09:25:31  2021-01-02 18:00:00
# 1  2021-01-03 09:24:48.000     2021-01-03 09:24:43  2021-01-02 09:24:43
# 2  2021-01-03 09:25:42.000                     NaN  2021-01-02 18:00:00
# 3  2021-01-03 09:25:39.000     2021-01-03 09:25:34  2021-01-02 18:00:00
# 4  2021-01-03 09:25:11.000     2021-01-03 09:25:06  2021-01-02 09:25:06

# %%
create_receipts_df_query = """
CREATE TABLE receipts (
    receipt_id VARCHAR(25) PRIMARY KEY,
    created_date_time DATETIME(3),
    scanned_date_time DATETIME(3),
    finished_date_time DATETIME(3),
    modify_date_time DATETIME(3),
    purchased_date_time DATETIME(3),
    pointsAwarded_date_time DATETIME(3),
    bonusPointsEarned DECIMAL(7,3),
    bonusPointsEarnedReason VARCHAR(35),
    pointsEarned DECIMAL(7,3),
    purchasedItemCount INT(7),
    rewardsReceiptStatus VARCHAR(10),
    totalSpent DECIMAL(7,3)
);
"""
run_query('DROP TABLE IF EXISTS receipts')
run_query(create_receipts_df_query)
# Out:
# Error in the query -> This result object does not return rows. It has been closed automatically.
# Error in the query -> This result object does not return rows. It has been closed automatically.

# %%
rewards_receipts_df.columns
# Out:
# Index(['barcode', 'description', 'finalPrice', 'itemPrice', 'needsFetchReview',
#        'partnerItemId', 'preventTargetGapPoints', 'quantityPurchased',
#        'userFlaggedBarcode', 'userFlaggedNewItem', 'userFlaggedPrice',
#        'userFlaggedQuantity', 'needsFetchReviewReason',
#        'pointsNotAwardedReason', 'pointsPayerId', 'rewardsGroup',
#        'rewardsProductPartnerId', 'userFlaggedDescription',
#        'originalMetaBriteBarcode', 'originalMetaBriteDescription', 'brandCode',
#        'competitorRewardsGroup', 'discountedItemPrice',
#        'originalReceiptItemText', 'itemNumber',
#        'originalMetaBriteQuantityPurchased', 'pointsEarned', 'targetPrice',
#        'competitiveProduct', 'originalFinalPrice',
#        'originalMetaBriteItemPrice', 'deleted', 'priceAfterCoupon',
#        'metabriteCampaignId', 'receipt_id'],
#       dtype='object')

# %%
rewards_receipts_df['needsFetchReview'] = rewards_receipts_df['needsFetchReview'].apply(lambda x:str(x).upper())
rewards_receipts_df['preventTargetGapPoints'] = rewards_receipts_df['preventTargetGapPoints'].apply(lambda x:str(x).upper())
rewards_receipts_df['userFlaggedNewItem'] = rewards_receipts_df['userFlaggedNewItem'].apply(lambda x:str(x).upper())
rewards_receipts_df['competitiveProduct'] = rewards_receipts_df['competitiveProduct'].apply(lambda x:str(x).upper())
rewards_receipts_df['deleted'] = rewards_receipts_df['deleted'].apply(lambda x:str(x).upper())

# %%
rewards_receipts_df['description_first_word'] = rewards_receipts_df['description'].apply(lambda x: x.split()[0] if pd.notna(x) else np.nan)

# %%
create_rewards_receipts_df_query = """
CREATE TABLE rewards_receipts (
    barcode VARCHAR(20),
    description VARCHAR(50),
    finalPrice DECIMAL(8,3),
    itemPrice DECIMAL(8,3),
    needsFetchReview Boolean,
    partnerItemId INT,
    preventTargetGapPoints Boolean,
    quantityPurchased DECIMAL(8,3),
    userFlaggedBarcode VARCHAR(20),
    userFlaggedNewItem BOOLEAN,
    userFlaggedPrice DECIMAL(8,3),
    userFlaggedQuantity DECIMAL(8,3),
    needsFetchReviewReason VARCHAR(20),
    pointsNotAwardedReason VARCHAR(50),
    pointsPayerId VARCHAR(25),
    rewardsGroup VARCHAR(20),
    rewardsProductPartnerId VARCHAR(25),
    userFlaggedDescription VARCHAR(50),
    originalMetaBriteBarcode VARCHAR(20),
    originalMetaBriteDescription VARCHAR(50),
    brandCode VARCHAR(20),
    competitorRewardsGroup VARCHAR(30),
    discountedItemPrice DECIMAL(8,3),
    originalReceiptItemText VARCHAR(50),
    itemNumber INT,
    originalMetaBriteQuantityPurchased DECIMAL(8,3),
    pointsEarned DECIMAL(8,3),
    targetPrice DECIMAL(8,3),
    competitiveProduct BOOLEAN,
    originalFinalPrice DECIMAL(8,3),
    originalMetaBriteItemPrice DECIMAL(8,3),
    deleted BOOLEAN,
    priceAfterCoupon DECIMAL(8,3),
    metabriteCampaignId VARCHAR(50),
    receipt_id VARCHAR(25),
    description_first_word VARCHAR(25),
    PRIMARY KEY (receipt_id,partnerItemId)    
);
"""
run_query('DROP TABLE IF EXISTS rewards_receipts')
run_query(create_rewards_receipts_df_query)
# Out:
# Error in the query -> This result object does not return rows. It has been closed automatically.
# Error in the query -> This result object does not return rows. It has been closed automatically.

# %%
### Time to load tables

#user_df
users_df_no_duplicates.to_sql('users',con = engine, if_exists = 'replace',index = False)

#brands_df
brands_df.to_sql('brands',con = engine, if_exists = 'replace',index = False)

#receipts_df
new_receipts_df.to_sql('receipts',con = engine, if_exists = 'replace',index = False)

#rewards_receipts_df
rewards_receipts_df.to_sql('rewards_receipts',con = engine, if_exists = 'replace',index = False)
# Out:
# 6941

# %%
rewards_receipts_df[(rewards_receipts_df['pointsEarned'] < 870)&(rewards_receipts_df['pointsEarned'] > 100)].head()
# Out:
#           barcode                                        description  \
# 623  076840100354  BEN & JERRYS FROZEN CHUNKY MONKEY ICE CREAM RE...
# 630  076840100354  BEN & JERRYS FROZEN CHUNKY MONKEY ICE CREAM RE...
# 634  076840580750  Ben & Jerry's Chunky Monkey Non-Dairy Frozen D...
# 635  076840580750  Ben & Jerry's Chunky Monkey Non-Dairy Frozen D...
# 636  076840100354  BEN & JERRYS FROZEN CHUNKY MONKEY ICE CREAM RE...
#
#      finalPrice  itemPrice needsFetchReview  partnerItemId  \
# 623       16.60      16.60              NAN           1011
# 630       21.30      21.30              NAN           1030
# 634       15.30      15.30              NAN           1017
# 635       28.70      28.70              NAN           1020
# 636       21.44      21.44              NAN           1023
#
#     preventTargetGapPoints  quantityPurchased  userFlaggedBarcode  \
# 623                    NAN                4.0                 NaN
# 630                    NAN                5.0                 NaN
# 634                    NAN                3.0                 NaN
# 635                    NAN                5.0                 NaN
# 636                    NAN                4.0                 NaN
#
#     userFlaggedNewItem  userFlaggedPrice  userFlaggedQuantity  \
# 623                NAN               NaN                  NaN
# 630                NAN               NaN                  NaN
# 634                NAN               NaN                  NaN
# 635                NAN               NaN                  NaN
# 636                NAN               NaN                  NaN
#
#     needsFetchReviewReason pointsNotAwardedReason             pointsPayerId  \
# 623                    NaN                    NaN  5332f5f6e4b03c9a25efd0b4
# 630                    NaN                    NaN  5332f5f6e4b03c9a25efd0b4
# 634                    NaN                    NaN  5332f5f6e4b03c9a25efd0b4
# 635                    NaN                    NaN  5332f5f6e4b03c9a25efd0b4
# 636                    NaN                    NaN  5332f5f6e4b03c9a25efd0b4
#
#                  rewardsGroup   rewardsProductPartnerId  \
# 623  BEN AND JERRYS ICE CREAM  5332f5f6e4b03c9a25efd0b4
# 630  BEN AND JERRYS ICE CREAM  5332f5f6e4b03c9a25efd0b4
# 634  BEN AND JERRYS ICE CREAM  5332f5f6e4b03c9a25efd0b4
# 635  BEN AND JERRYS ICE CREAM  5332f5f6e4b03c9a25efd0b4
# 636  BEN AND JERRYS ICE CREAM  5332f5f6e4b03c9a25efd0b4
#
#     userFlaggedDescription  originalMetaBriteBarcode  \
# 623                    NaN                       NaN
# 630                    NaN                       NaN
# 634                    NaN                       NaN
# 635                    NaN                       NaN
# 636                    NaN                       NaN
#
#     originalMetaBriteDescription       brandCode competitorRewardsGroup  \
# 623                          NaN  BEN AND JERRYS                    NaN
# 630                          NaN  BEN AND JERRYS                    NaN
# 634                          NaN  BEN AND JERRYS                    NaN
# 635                          NaN  BEN AND JERRYS                    NaN
# 636                          NaN  BEN AND JERRYS                    NaN
#
#      discountedItemPrice            originalReceiptItemText  itemNumber  \
# 623                16.60  BEN & JERRY' S CHUNKY MONKEY PINT         NaN
# 630                21.30   BEN 6 JERRY.S CHUN*Y MONKEY PINT         NaN
# 634                15.30  BEN & JERRY' S CHUNKY MONKEY PINT         NaN
# 635                28.70  BEN & JERRY' S CHUNKY MONKEY PINT         NaN
# 636                21.44  BEN & JERRY' S CHUNKY MONKEY PINT         NaN
#
#      originalMetaBriteQuantityPurchased  pointsEarned  targetPrice  \
# 623                                 NaN         166.0          NaN
# 630                                 NaN         213.0          NaN
# 634                                 NaN         153.0          NaN
# 635                                 NaN         287.0          NaN
# 636                                 NaN         214.4          NaN
#
#     competitiveProduct  originalFinalPrice  originalMetaBriteItemPrice  \
# 623                NAN                 NaN                         NaN
# 630                NAN                 NaN                         NaN
# 634                NAN                 NaN                         NaN
# 635                NAN                 NaN                         NaN
# 636                NAN                 NaN                         NaN
#
#     deleted  priceAfterCoupon       metabriteCampaignId  \
# 623     NAN               NaN  BEN AND JERRYS ICE CREAM
# 630     NAN               NaN  BEN AND JERRYS ICE CREAM
# 634     NAN               NaN  BEN AND JERRYS ICE CREAM
# 635     NAN               NaN  BEN AND JERRYS ICE CREAM
# 636     NAN               NaN  BEN AND JERRYS ICE CREAM
#
#                    receipt_id description_first_word
# 623  6000b2be0a7214ad4c00004d                    BEN
# 630  6000b2be0a7214ad4c00004d                    BEN
# 634  6000c8460a720f05f300006f                    Ben
# 635  6000c8460a720f05f300006f                    Ben
# 636  6000c8460a720f05f300006f                    BEN

# %%
receipts_df['scanned_date_time'].dt.strftime('%Y-%m')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33756\736383058.py in <module>
# ----> 1 receipts_df['scanned_date_time'].dt.strftime('%Y-%m')
#
# c:\Users\pragn\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# c:\Users\pragn\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# c:\Users\pragn\anaconda3\lib\site-packages\pandas\core\indexes\accessors.py in __new__(cls, data)
#     507             return PeriodProperties(data, orig)
#     508
# --> 509         raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
receipts_df['scan_check'] = pd.to_datetime(receipts_df['scanned_date_time'], format='%Y-%m')
receipts_df['scan_check'] = receipts_df['scan_check'].dt.strftime('%Y-%m')
receipts_df['scan_check'].head()
# Out:
# 0    2021-01
# 1    2021-01
# 2    2021-01
# 3    2021-01
# 4    2021-01
# Name: scan_check, dtype: object

# %%
rewards_receipts_df[rewards_receipts_df['receipt_id']=='603cbbb50a720fde100003e3']
# Out:
#          barcode                                        description  \
# 6915  B076FJ92M4  mueller austria hypergrind precision electric ...
# 6916  B07BRRLSVC  thindust summer face mask - sun protection nec...
#
#       finalPrice  itemPrice needsFetchReview  partnerItemId  \
# 6915       22.97      22.97              NAN              0
# 6916       11.99      11.99              NAN              1
#
#      preventTargetGapPoints  quantityPurchased  userFlaggedBarcode  \
# 6915                    NAN                1.0                 NaN
# 6916                    NAN                1.0                 NaN
#
#      userFlaggedNewItem  userFlaggedPrice  userFlaggedQuantity  \
# 6915                NAN               NaN                  NaN
# 6916                NAN               NaN                  NaN
#
#      needsFetchReviewReason pointsNotAwardedReason pointsPayerId rewardsGroup  \
# 6915                    NaN                    NaN           NaN          NaN
# 6916                    NaN                    NaN           NaN          NaN
#
#      rewardsProductPartnerId userFlaggedDescription  originalMetaBriteBarcode  \
# 6915                     NaN                    NaN                       NaN
# 6916                     NaN                    NaN                       NaN
#
#      originalMetaBriteDescription brandCode competitorRewardsGroup  \
# 6915                          NaN       NaN                    NaN
# 6916                          NaN       NaN                    NaN
#
#       discountedItemPrice                            originalReceiptItemText  \
# 6915                22.97  mueller austria hypergrind precision electric ...
# 6916                11.99  thindust summer face mask - sun protection nec...
#
#       itemNumber  originalMetaBriteQuantityPurchased  pointsEarned  \
# 6915         NaN                                 NaN           NaN
# 6916         NaN                                 NaN           NaN
#
#       targetPrice competitiveProduct  originalFinalPrice  \
# 6915          NaN                NAN                 NaN
# 6916          NaN                NAN                 NaN
#
#       originalMetaBriteItemPrice deleted  priceAfterCoupon  \
# 6915                         NaN     NAN             22.97
# 6916                         NaN     NAN             11.99
#
#      metabriteCampaignId                receipt_id description_first_word
# 6915                 NaN  603cbbb50a720fde100003e3                mueller
# 6916                 NaN  603cbbb50a720fde100003e3               thindust

# %%
receipts_df[receipts_df['scan_check'] == '2021-03'].head()
# Out:
#       bonusPointsEarned      bonusPointsEarnedReason  pointsEarned  \
# 1089               25.0  COMPLETE_NONPARTNER_RECEIPT          25.0
# 1090                NaN                          NaN           NaN
# 1091                NaN                          NaN           NaN
# 1092               25.0  COMPLETE_NONPARTNER_RECEIPT          25.0
# 1094               25.0  COMPLETE_NONPARTNER_RECEIPT          25.0
#
#       purchasedItemCount                             rewardsReceiptItemList  \
# 1089                 2.0  [{'barcode': 'B076FJ92M4', 'description': 'mue...
# 1090                 NaN                                                NaN
# 1091                 NaN                                                NaN
# 1092                 2.0  [{'barcode': 'B076FJ92M4', 'description': 'mue...
# 1094                 2.0  [{'barcode': 'B076FJ92M4', 'description': 'mue...
#
#      rewardsReceiptStatus  totalSpent                    userId  \
# 1089             REJECTED       34.96  5fc961c3b8cfca11a077dd33
# 1090            SUBMITTED         NaN  5fc961c3b8cfca11a077dd33
# 1091            SUBMITTED         NaN  5fc961c3b8cfca11a077dd33
# 1092             REJECTED       34.96  5fc961c3b8cfca11a077dd33
# 1094             REJECTED       34.96  5fc961c3b8cfca11a077dd33
#
#                     receipt_id        created_date_time  \
# 1089  603cbbb50a720fde100003e3  2021-03-01 04:02:29.000
# 1090  603cadab0a720fde100003d6  2021-03-01 03:02:35.175
# 1091  603c8cdf0a7217c72c0003bb  2021-03-01 00:42:39.190
# 1092  603d30e60a7217c72c00043f  2021-03-01 12:22:30.000
# 1094  603d5d6c0a7217c72c000463  2021-03-01 15:32:28.000
#
#             scanned_date_time finished_date_time         modify_date_time  \
# 1089  2021-03-01 04:02:29.000                NaN  2021-03-01 04:02:30.000
# 1090  2021-03-01 03:02:35.175                NaN  2021-03-01 03:02:35.175
# 1091  2021-03-01 00:42:39.190                NaN  2021-03-01 00:42:39.190
# 1092  2021-03-01 12:22:30.000                NaN  2021-03-01 12:22:31.000
# 1094  2021-03-01 15:32:28.000                NaN  2021-03-01 15:32:29.000
#
#      pointsAwarded_date_time  purchased_date_time scan_check
# 1089                     NaN  2020-08-16 19:00:00    2021-03
# 1090                     NaN                  NaN    2021-03
# 1091                     NaN                  NaN    2021-03
# 1092                     NaN  2020-08-16 19:00:00    2021-03
# 1094                     NaN  2020-08-16 19:00:00    2021-03
